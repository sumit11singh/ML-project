# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv")

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %%
df['fraud_reported'].sort_values()
# Out:
# 499    N
# 612    N
# 613    N
# 614    N
# 615    N
#       ..
# 171    Y
# 558    Y
# 561    Y
# 567    Y
# 0      Y
# Name: fraud_reported, Length: 1000, dtype: object

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %% [markdown]
# _c39 has the total null values so it seems it does not have any contribution with label so drop this column

# %% [markdown]
# # EDA Analysis(Data Visulization)

# %%
sns.distplot(df['months_as_customer'])
# Out:
# <AxesSubplot:xlabel='months_as_customer', ylabel='Density'>

# %%
sns.boxplot(df['months_as_customer'])
# Out:
# <AxesSubplot:xlabel='months_as_customer'>

# %% [markdown]
# at above graph is showing that max customer in a month lies b/w 110 to 290.

# %%
sns.boxplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# Most of aplicant has the age in b/w 32 yrs to 45yrs

# %%
sns.distplot(df['umbrella_limit'])
# Out:
# <AxesSubplot:xlabel='umbrella_limit', ylabel='Density'>

# %%
sns.countplot(df['police_report_available'])
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='count'>

# %% [markdown]
# above grapgh is showing that police report is available for no of people=320,police report is not avialble for 340 no's of people applied for Loan while 340 applicant are lying in doubltfull satuiation.

# %%
sns.countplot(df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='count'>

# %%
sns.boxplot(df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='total_claim_amount'>

# %% [markdown]
# Majority for Total claim amount claimed by the customer is lying in b/w 40000rs to 70000rs

# %%
sns.boxplot(df['injury_claim'])
# Out:
# <AxesSubplot:xlabel='injury_claim'>

# %% [markdown]
# Majority of customers are claiming Injury claim in b/w 4000rs to 130000rs

# %%
sns.boxplot(df['property_claim'])
# Out:
# <AxesSubplot:xlabel='property_claim'>

# %%
sns.boxplot(df['vehicle_claim'])
# Out:
# <AxesSubplot:xlabel='vehicle_claim'>

# %%
plt.figure(figsize=(30,15))
sns.countplot(df['auto_make'])
# Out:
# <AxesSubplot:xlabel='auto_make', ylabel='count'>

# %% [markdown]
# these are the different auto_make showing in above plot

# %%
plt.figure(figsize=(30,15))
sns.countplot(df['auto_model'])
# Out:
# <AxesSubplot:xlabel='auto_model', ylabel='count'>

# %% [markdown]
# following graph is showing that there are count for various auto models against which claim is claimed by customer

# %%
plt.figure(figsize=(30,15))
sns.countplot(df['auto_model'])
# Out:
# <AxesSubplot:xlabel='auto_model', ylabel='count'>

# %% [markdown]
# # Label or O/P EDA Analysis

# %%
sns.countplot(df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Following Grapgh is showing that actual cases which are reported are 780 no's while Fraud cases are approx 220 no's.

# %%
sns.scatterplot(df['fraud_reported'],df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='total_claim_amount'>

# %%
sns.boxplot(df['fraud_reported'],df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='total_claim_amount'>

# %% [markdown]
# in Fraud case amount claimed by customer is in b/w 45000 to75000rs while in Fraud case the total claimed amount is in b/w 30000rs to 64000 rs

# %% [markdown]
# # _c39 has no contribution with Label variable so drop this column

# %%
df1=df.drop('_c39',axis=1)

# %%
df1
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df1.shape
# Out:
# (1000, 39)

# %%
df1.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %% [markdown]
# now _c39 column has been removed fron orginal Dataset

# %%
df1['fraud_reported'].value_counts()
# Out:
# N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %% [markdown]
# # Use OrdinalEncoder method to convert string values into Numeruic values

# %%
from sklearn.preprocessing import OrdinalEncoder
en=OrdinalEncoder()

# %%
 for i in df1.columns:
    if df1[i].dtypes=='object':
        df1[i]=en.fit_transform(df[i].values.reshape(-1,1))

# %%
df1
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585             532.0           2.0
# 1                   228   42         342868             821.0           1.0
# 2                   134   29         687698             186.0           2.0
# 3                   256   41         227811             766.0           0.0
# 4                   228   44         367455             181.0           0.0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851             487.0           2.0
# 996                 285   41         186934             129.0           0.0
# 997                 130   34         918516             509.0           2.0
# 998                 458   62         533940             573.0           0.0
# 999                 456   60         556080             359.0           2.0
#
# ...

# %%
df1['fraud_reported'].sort_values()
# Out:
# 499    0.0
# 612    0.0
# 613    0.0
# 614    0.0
# 615    0.0
#       ...
# 171    1.0
# 558    1.0
# 561    1.0
# 567    1.0
# 0      1.0
# Name: fraud_reported, Length: 1000, dtype: float64

# %%
df1['fraud_reported'].value_counts()
# Out:
# 0.0    753
# 1.0    247
# Name: fraud_reported, dtype: int64

# %% [markdown]
# # Finding Correaltion for given Dataset

# %%
df1.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_bind_date                       0.055055  0.056538       0.045713
# policy_state                          -0.000328 -0.014533       0.072815
# policy_csl                            -0.026819 -0.015185       0.038917
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# insured_sex                            0.060925  0.073337       0.004564
# insured_education_level               -0.000833  0.000969      -0.037264
# ...

# %%
df1.corr()['fraud_reported'].sort_values()
# Out:
# incident_severity             -0.405988
# incident_state                -0.051407
# incident_type                 -0.050376
# incident_date                 -0.047726
# insured_hobbies               -0.046838
# authorities_contacted         -0.045802
# incident_city                 -0.040403
# policy_csl                    -0.037190
# property_damage               -0.030497
# policy_number                 -0.029443
# police_report_available       -0.028159
# auto_make                     -0.027519
# capital-gains                 -0.019173
# capital-loss                  -0.014863
# policy_annual_premium         -0.014480
# incident_location             -0.008832
# auto_model                     0.000720
# insured_occupation             0.001564
# incident_hour_of_the_day       0.004316
# auto_year                      0.007928
# insured_education_level        0.008808
# age                            0.012143
# policy_deductable              0.014817
# ...

# %% [markdown]
# above Equation is showing the corr of each i/p cloumn varaiables with Label varaiable .some have the -ve corelation with label varaible & some have +ve with lable varaiable.

# %% [markdown]
# # Using HeatMap method for finding Corelation for O/P variable with other i/p variables

# %%
plt.figure(figsize=(40,40))
sns.heatmap(df1.corr(),annot=True,linewidths=.5,linecolor="Black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Describing the Given Dataset

# %%
df1.describe()
# Out:
#        months_as_customer          age  policy_number  policy_bind_date  \
# count         1000.000000  1000.000000    1000.000000       1000.000000
# mean           203.954000    38.948000  546238.648000        474.332000
# std            115.113174     9.140287  257063.005276        275.402851
# min              0.000000    19.000000  100804.000000          0.000000
# 25%            115.750000    32.000000  335980.250000        233.750000
# 50%            199.500000    38.000000  533135.000000        472.500000
# 75%            276.250000    44.000000  759099.750000        713.250000
# max            479.000000    64.000000  999435.000000        950.000000
#
#        policy_state   policy_csl  policy_deductable  policy_annual_premium  \
# count    1000.00000  1000.000000        1000.000000            1000.000000
# mean        1.01400     0.951000        1136.000000            1256.406150
# std         0.83096     0.804516         611.864673             244.167395
# ...

# %% [markdown]
# # Plotting Heatmap

# %%
plt.figure(figsize=(40,20))
sns.heatmap(round(df1.describe()[1:].transpose(),2),annot=True,linewidths=.2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking Outliers in given Dataset¶

# %%
df1.plot(kind='box',subplots=True,layout=(9,6),figsize=(40,20))
# Out:
# months_as_customer                AxesSubplot(0.125,0.808774;0.110714x0.0712264)
# age                            AxesSubplot(0.257857,0.808774;0.110714x0.0712264)
# policy_number                  AxesSubplot(0.390714,0.808774;0.110714x0.0712264)
# policy_bind_date               AxesSubplot(0.523571,0.808774;0.110714x0.0712264)
# policy_state                   AxesSubplot(0.656429,0.808774;0.110714x0.0712264)
# policy_csl                     AxesSubplot(0.789286,0.808774;0.110714x0.0712264)
# policy_deductable                 AxesSubplot(0.125,0.723302;0.110714x0.0712264)
# policy_annual_premium          AxesSubplot(0.257857,0.723302;0.110714x0.0712264)
# umbrella_limit                 AxesSubplot(0.390714,0.723302;0.110714x0.0712264)
# insured_zip                    AxesSubplot(0.523571,0.723302;0.110714x0.0712264)
# insured_sex                    AxesSubplot(0.656429,0.723302;0.110714x0.0712264)
# insured_education_level        AxesSubplot(0.789286,0.723302;0.110714x0.0712264)
# ...

# %% [markdown]
# # Use zscore method for removing outliers from given dataset

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))

# %%
z
# Out:
#      months_as_customer       age  policy_number  policy_bind_date  \
# 0              1.078140  0.990836       0.095953          0.209500
# 1              0.208995  0.334073       0.791527          1.259397
# 2              0.608002  1.088913       0.550566          1.047470
# 3              0.452355  0.224613       1.239334          1.059589
# 4              0.208995  0.552994       0.695834          1.065634
# ..                  ...       ...            ...               ...
# 995            1.746582  0.103769       1.539740          0.046021
# 996            0.704407  0.224613       1.398429          1.254543
# 997            0.642767  0.541611       1.448920          0.125944
# 998            2.208028  2.523284       0.047867          0.358447
# 999            2.190645  2.304363       0.038303          0.418985
#
#      policy_state  policy_csl  policy_deductable  policy_annual_premium  \
# 0        1.187173    0.060937           0.222383               0.616705
# ...

# %%
thresold=3
print(np.where(z>3))
# Out:
# (array([ 31,  48,  88, 115, 119, 229, 248, 262, 314, 430, 458, 500, 503,
#        657, 700, 763, 807, 875, 922, 975], dtype=int64), array([ 8,  8,  8,  8,  8,  7,  7,  8,  8,  8,  8, 33,  8,  8,  8,  7, 16,
#         8,  8,  8], dtype=int64))

# %%
df1_new=df1[(z<3).all(axis=1)]

# %%
print('Old_dataframe',df1.shape)
print('new_dataframe',df1_new.shape)
print("reduction in rows",df1.shape[0]-df1_new.shape[0])
# Out:
# Old_dataframe (1000, 39)
# new_dataframe (980, 39)
# reduction in rows 20

# %%
Percentage_dataloss=(1000-980)/1000*100

# %%
Percentage_dataloss
# Out:
# 2.0

# %% [markdown]
# # spliting the Data in Training & Tesing phase

# %%
x=df1_new.drop('fraud_reported',axis=1)

# %%
x
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585             532.0           2.0
# 1                   228   42         342868             821.0           1.0
# 2                   134   29         687698             186.0           2.0
# 3                   256   41         227811             766.0           0.0
# 4                   228   44         367455             181.0           0.0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851             487.0           2.0
# 996                 285   41         186934             129.0           0.0
# 997                 130   34         918516             509.0           2.0
# 998                 458   62         533940             573.0           0.0
# 999                 456   60         556080             359.0           2.0
#
# ...

# %%
y=df1_new['fraud_reported']

# %%
y
# Out:
# 0      1.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      0.0
#       ...
# 995    0.0
# 996    0.0
# 997    0.0
# 998    0.0
# 999    0.0
# Name: fraud_reported, Length: 980, dtype: float64

# %% [markdown]
# # check skewness present in Datset

# %%
x.skew()
# Out:
# months_as_customer             0.362608
# age                            0.475385
# policy_number                  0.036283
# policy_bind_date               0.006386
# policy_state                  -0.038157
# policy_csl                     0.098248
# policy_deductable              0.476090
# policy_annual_premium          0.035964
# umbrella_limit                 1.801424
# insured_zip                    0.837283
# insured_sex                    0.139324
# insured_education_level        0.006286
# insured_occupation            -0.055360
# insured_hobbies               -0.061488
# insured_relationship           0.078339
# capital-gains                  0.466619
# capital-loss                  -0.376884
# incident_date                  0.002604
# incident_type                  0.090563
# collision_type                -0.194015
# incident_severity              0.277726
# authorities_contacted         -0.114044
# incident_state                -0.149255
# ...

# %%
df1.plot(kind='density',subplots=True,layout=(8,6),figsize=(40,32))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %% [markdown]
# there are some skewness present in given Dataset

# %% [markdown]
# # Transformimg Data to remove skewness

# %% [markdown]
# Using the power transforming method to remove Skewness present in the given dataset

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.04454111,  1.0023305 , -0.02347493, ...,  0.85481164,
#         -1.80721231, -0.20443508],
#        [ 0.29904549,  0.42717141, -0.74401221, ...,  0.41187331,
#         -0.57848628,  0.29587688],
#        [-0.51581942, -1.13601305,  0.58680474, ..., -0.56458381,
#          0.9504262 ,  0.29587688],
#        ...,
#        [-0.55427228, -0.47059792,  1.37172562, ...,  1.06823592,
#          0.05320514, -1.49935977],
#        [ 1.90408801,  2.12107486,  0.02357929, ..., -1.44793034,
#         -1.29996796, -1.18090064],
#        [ 1.89156317,  1.97656406,  0.10716503, ...,  0.41187331,
#         -0.57848628,  0.29587688]])

# %% [markdown]
# # MIN values & MAX values difference is higher in Describe dataset so use the scaling method to scale the data

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 1.04454111,  1.0023305 , -0.02347493, ...,  0.85481164,
#         -1.80721231, -0.20443508],
#        [ 0.29904549,  0.42717141, -0.74401221, ...,  0.41187331,
#         -0.57848628,  0.29587688],
#        [-0.51581942, -1.13601305,  0.58680474, ..., -0.56458381,
#          0.9504262 ,  0.29587688],
#        ...,
#        [-0.55427228, -0.47059792,  1.37172562, ...,  1.06823592,
#          0.05320514, -1.49935977],
#        [ 1.90408801,  2.12107486,  0.02357929, ..., -1.44793034,
#         -1.29996796, -1.18090064],
#        [ 1.89156317,  1.97656406,  0.10716503, ...,  0.41187331,
#         -0.57848628,  0.29587688]])

# %% [markdown]
# # spliting the data for training & testing phase

# %% [markdown]
# O/P is in Binary form ,Use LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
lg=LogisticRegression()

# %%
for i in range(0,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=i)
        lg.fit(train_x,train_y)
        lgpred=lg.predict(test_x)
        print(f"at random_state{i},the testing accuracy score is := {accuracy_score(test_y,lgpred)}")
        print(f"at random_state{i},the training accuracy is: =   {lg.score(train_x,train_y)}")
# Out:
# at random_state0,the testing accuracy score is := 0.7857142857142857
# at random_state0,the training accuracy is: =   0.8073979591836735
# at random_state1,the testing accuracy score is := 0.7908163265306123
# at random_state1,the training accuracy is: =   0.8137755102040817
# at random_state2,the testing accuracy score is := 0.75
# at random_state2,the training accuracy is: =   0.8099489795918368
# at random_state3,the testing accuracy score is := 0.8163265306122449
# at random_state3,the training accuracy is: =   0.7971938775510204
# at random_state4,the testing accuracy score is := 0.8061224489795918
# at random_state4,the training accuracy is: =   0.8137755102040817
# at random_state5,the testing accuracy score is := 0.7653061224489796
# at random_state5,the training accuracy is: =   0.8201530612244898
# at random_state6,the testing accuracy score is := 0.8112244897959183
# at random_state6,the training accuracy is: =   0.8048469387755102
# ...

# %%
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=79)
        lg.fit(train_x,train_y)
        lgpred=lg.predict(test_x)
        print(f"at random_state{79},the testing accuracy score is := {accuracy_score(test_y,lgpred)}")
        print(f"at random_state{79},the training accuracy is: =   {lg.score(train_x,train_y)}")
# Out:
# at random_state79,the testing accuracy score is := 0.8010204081632653
# at random_state79,the training accuracy is: =   0.8112244897959183

# %% [markdown]
# # AUC & ROC Curve

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=lg.predict_proba(test_x)[:,1]

# %%
y_pred_prob
# Out:
# array([0.16478167, 0.05420263, 0.08026267, 0.22077645, 0.10396667,
#        0.09215918, 0.05122492, 0.18503   , 0.03365947, 0.08620102,
#        0.54197794, 0.06542009, 0.54222314, 0.57151703, 0.19215894,
#        0.07727491, 0.68235041, 0.35758176, 0.05186735, 0.08655118,
#        0.0188584 , 0.20805616, 0.03250682, 0.18038408, 0.30001794,
#        0.57435447, 0.2454364 , 0.48460306, 0.19112592, 0.21816799,
#        0.22154693, 0.318444  , 0.09401331, 0.07963109, 0.08732217,
#        0.3118217 , 0.128718  , 0.29803931, 0.41202954, 0.52988809,
#        0.19628596, 0.38642474, 0.08855374, 0.11987604, 0.6798868 ,
#        0.072096  , 0.52535295, 0.07351996, 0.18046647, 0.17907687,
#        0.04655809, 0.12495175, 0.63677561, 0.15816343, 0.54443431,
#        0.66303193, 0.13884156, 0.61966057, 0.02009908, 0.13197902,
#        0.1965684 , 0.15983828, 0.0255259 , 0.02690346, 0.2597836 ,
#        0.06414224, 0.21065742, 0.14562722, 0.23812504, 0.02947964,
# ...

# %%
fpr,tpr,thresold=roc_curve(test_y,y_pred_prob)

# %%
fpr
# Out:
# array([0.        , 0.00649351, 0.00649351, 0.03896104, 0.03896104,
#        0.06493506, 0.06493506, 0.07142857, 0.07142857, 0.07792208,
#        0.07792208, 0.08441558, 0.08441558, 0.09090909, 0.09090909,
#        0.0974026 , 0.0974026 , 0.1038961 , 0.1038961 , 0.11038961,
#        0.11038961, 0.11688312, 0.11688312, 0.16883117, 0.16883117,
#        0.17532468, 0.17532468, 0.18831169, 0.18831169, 0.19480519,
#        0.19480519, 0.22727273, 0.22727273, 0.24025974, 0.24025974,
#        0.24675325, 0.24675325, 0.2987013 , 0.2987013 , 0.35714286,
#        0.35714286, 0.4025974 , 0.4025974 , 0.44155844, 0.44155844,
#        0.44805195, 0.44805195, 0.46103896, 0.46103896, 0.55844156,
#        0.55844156, 0.77922078, 0.77922078, 0.82467532, 0.82467532,
#        0.85714286, 0.85714286, 1.        ])

# %%
tpr
# Out:
# array([0.        , 0.        , 0.02380952, 0.02380952, 0.04761905,
#        0.04761905, 0.11904762, 0.11904762, 0.14285714, 0.14285714,
#        0.35714286, 0.35714286, 0.4047619 , 0.4047619 , 0.42857143,
#        0.42857143, 0.45238095, 0.45238095, 0.5       , 0.5       ,
#        0.54761905, 0.54761905, 0.57142857, 0.57142857, 0.5952381 ,
#        0.5952381 , 0.61904762, 0.61904762, 0.64285714, 0.64285714,
#        0.66666667, 0.66666667, 0.69047619, 0.69047619, 0.73809524,
#        0.73809524, 0.76190476, 0.76190476, 0.78571429, 0.78571429,
#        0.80952381, 0.80952381, 0.83333333, 0.83333333, 0.85714286,
#        0.85714286, 0.88095238, 0.88095238, 0.9047619 , 0.9047619 ,
#        0.92857143, 0.92857143, 0.95238095, 0.95238095, 0.97619048,
#        0.97619048, 1.        , 1.        ])

# %%
thresold
# Out:
# array([1.6987564 , 0.6987564 , 0.68648589, 0.65050079, 0.64265306,
#        0.60974662, 0.57435447, 0.57151703, 0.56940107, 0.56850872,
#        0.54197794, 0.541922  , 0.53279659, 0.52988809, 0.52626809,
#        0.52548336, 0.52535295, 0.515706  , 0.48170061, 0.41901276,
#        0.3908618 , 0.38642474, 0.38634968, 0.34371827, 0.34099295,
#        0.33235241, 0.32781575, 0.32267815, 0.318444  , 0.3118217 ,
#        0.3105499 , 0.28501894, 0.28366229, 0.2597836 , 0.24631903,
#        0.2454364 , 0.24309491, 0.22572767, 0.22325532, 0.1965684 ,
#        0.19628596, 0.18046647, 0.18038408, 0.16704664, 0.16635625,
#        0.1654141 , 0.16478167, 0.15983828, 0.15927114, 0.12495175,
#        0.12163012, 0.06779248, 0.06542009, 0.05420263, 0.05186735,
#        0.04578728, 0.03864074, 0.00892793])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label="Logistic Regression")
plt.xlabel("False Postive Rate")
plt.ylabel("True Postive Rate")
plt.title("Logistic Regression")
plt.show()

# %%
roc_score=roc_auc_score(test_y,y_pred_prob)
roc_score
# Out:
# 0.785095856524428

# %% [markdown]
# Hence the roc_auc score for Logistic Regression Model is 78.5%

# %% [markdown]
# # crossvalidation

# %% [markdown]
# # Classifiers

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)
svc=SVC()
gnb= GaussianNB()
dtc=DecisionTreeClassifier()

# %% [markdown]
# # Use KNeighbors Model

# %%
for i in range(2,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.22,random_state=i)

        knn.fit(train_x,train_y)
        predknn=knn.predict(test_x)
        print(f"at random_state{i},the testing accuracy score is := {accuracy_score(test_y,predknn)}")
        print(f"at random_state{i},the training accuracy is: =      {knn.score(train_x,train_y)}")
        print(f"at random_state{i},the confusion_matrix is:=        {confusion_matrix(test_y,predknn)}")
        print(f"at random_state{i},the classification_report is:=   {classification_report(test_y,predknn)}")
        print("\n")
# Out:
# at random_state2,the testing accuracy score is := 0.7083333333333334
# at random_state2,the training accuracy is: =      0.7918848167539267
# at random_state2,the confusion_matrix is:=        [[147  12]
#  [ 51   6]]
# at random_state2,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.74      0.92      0.82       159
#          1.0       0.33      0.11      0.16        57
#
#     accuracy                           0.71       216
#    macro avg       0.54      0.51      0.49       216
# weighted avg       0.63      0.71      0.65       216
#
#
#
# at random_state3,the testing accuracy score is := 0.7407407407407407
# at random_state3,the training accuracy is: =      0.7958115183246073
# at random_state3,the confusion_matrix is:=        [[150  15]
#  [ 41  10]]
# at random_state3,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.79      0.91      0.84       165
# ...

# %% [markdown]
# accuracy for KNN model at random state =79 is less than than LogisticRegression so this model is not best fit for production purpose

# %% [markdown]
# # Use Gaussian Model

# %%
for i in range(2,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.22,random_state=i)

        gnb.fit(train_x,train_y)
        predgnb=gnb.predict(test_x)
        print(f"at random_state{i},the testing accuracy score is := {accuracy_score(test_y,predgnb)}")
        print(f"at random_state{i},the training accuracy is: =      {gnb.score(train_x,train_y)}")
        print(f"at random_state{i},the confusion_matrix is:=        {confusion_matrix(test_y,predgnb)}")
        print(f"at random_state{i},the classification_report is:=   {classification_report(test_y,predgnb)}")
        print("\n")
# Out:
# at random_state2,the testing accuracy score is := 0.7222222222222222
# at random_state2,the training accuracy is: =      0.7539267015706806
# at random_state2,the confusion_matrix is:=        [[119  40]
#  [ 20  37]]
# at random_state2,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.86      0.75      0.80       159
#          1.0       0.48      0.65      0.55        57
#
#     accuracy                           0.72       216
#    macro avg       0.67      0.70      0.68       216
# weighted avg       0.76      0.72      0.73       216
#
#
#
# at random_state3,the testing accuracy score is := 0.7222222222222222
# at random_state3,the training accuracy is: =      0.7369109947643979
# at random_state3,the confusion_matrix is:=        [[120  45]
#  [ 15  36]]
# at random_state3,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.73      0.80       165
# ...

# %% [markdown]
# accuracy for GAussian model at random state =79 is less than than LogisticRegression so this model is not best fit for production purpose

# %% [markdown]
# # Use GRIDSEARCHCV

# %%
from sklearn.model_selection import GridSearchCV
dtc=DecisionTreeClassifier()

# %%
grid_param={'criterion':['ginni','entropy']}
grid=GridSearchCV(dtc,grid_param)
grid.fit(train_x,train_y)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['ginni', 'entropy']})

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'entropy'}

# %%
dtc=DecisionTreeClassifier(criterion='entropy')
dtc.fit(train_x,train_y)
dtcpred=dtc.predict(test_x)
print(f"dtc training score is:= {dtc.score(train_x,train_y)}")
print(f"dtc testing score is:= {accuracy_score(test_y,dtcpred)}")
print(f"confusion matrix is:={confusion_matrix(test_y,dtcpred)}")
print(f"classification report is:={classification_report(test_y,dtcpred)}")
# Out:
# dtc training score is:= 1.0
# dtc testing score is:= 0.7361111111111112
# confusion matrix is:=[[128  26]
#  [ 31  31]]
# classification report is:=              precision    recall  f1-score   support
#
#          0.0       0.81      0.83      0.82       154
#          1.0       0.54      0.50      0.52        62
#
#     accuracy                           0.74       216
#    macro avg       0.67      0.67      0.67       216
# weighted avg       0.73      0.74      0.73       216

# %% [markdown]
# accuracy for dtc model is less than the LogisticRegression model

# %% [markdown]
# # SVC classifier

# %%
grid_param={'kernel':['rbf','poly','linear']}
grid=GridSearchCV(svc,grid_param)
grid.fit(train_x,train_y)
# Out:
# GridSearchCV(estimator=SVC(), param_grid={'kernel': ['rbf', 'poly', 'linear']})

# %%
print(grid.best_params_)
# Out:
# {'kernel': 'linear'}

# %%
svc=SVC()
svc.fit(train_x,train_y)
svcpred=svc.predict(test_x)
print(f"svc training score is:= {svc.score(train_x,train_y)}")
print(f"svc testing score is:= {accuracy_score(test_y,svcpred)}")
print(f"confusion matrix is:={confusion_matrix(test_y,svcpred)}")
print(f"classification report is:={classification_report(test_y,svcpred)}")
# Out:
# svc training score is:= 0.9083769633507853
# svc testing score is:= 0.7129629629629629
# confusion matrix is:=[[146   8]
#  [ 54   8]]
# classification report is:=              precision    recall  f1-score   support
#
#          0.0       0.73      0.95      0.82       154
#          1.0       0.50      0.13      0.21        62
#
#     accuracy                           0.71       216
#    macro avg       0.61      0.54      0.51       216
# weighted avg       0.66      0.71      0.65       216

# %% [markdown]
# accuracy for svc model is less than the LogisticRegression model

# %% [markdown]
# # Ensemble Technique

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=550,random_state=42)
rf.fit(train_x,train_y)
rfpred=rf.predict(test_x)
print(f"rf training score is:= {rf.score(train_x,train_y)}")
print(f"rf testing score is:= {accuracy_score(test_y,rfpred)}")
print(f"confusion matrix is:={confusion_matrix(test_y,rfpred)}")
print(f"classification report is:={classification_report(test_y,rfpred)}")
# Out:
# rf training score is:= 1.0
# rf testing score is:= 0.7361111111111112
# confusion matrix is:=[[140  14]
#  [ 43  19]]
# classification report is:=              precision    recall  f1-score   support
#
#          0.0       0.77      0.91      0.83       154
#          1.0       0.58      0.31      0.40        62
#
#     accuracy                           0.74       216
#    macro avg       0.67      0.61      0.62       216
# weighted avg       0.71      0.74      0.71       216

# %% [markdown]
# # Use Crossvaltidation Technique

# %% [markdown]
# check CV score for lg model

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_score=cross_val_score(lg,x,y,cv=5)
mean_accuracy=cv_score.mean()

# %%
mean_accuracy
# Out:
# 0.7867346938775511

# %% [markdown]
# it shows that lg model is get overfitted because the cv score of lg model are lesser than Lg score.hence the model accuracy is 78.67% thats showing is very gd

# %% [markdown]
# check CV score for Random Forest Classifier model

# %%
cv_score=cross_val_score(rf,x,y,cv=5)
mean_accuracy=cv_score.mean()

# %%
mean_accuracy
# Out:
# 0.7591836734693878

# %% [markdown]
# # Predicting the best performance for the given model

# %% [markdown]
# hence among all the model it is showing that LogisticRegression model is the best performing with Training accuracy=81.12% ,testing accuracy score=80.1%,cv score=78.67%

# %% [markdown]
# # Save the model for Production purpose

# %%
import joblib
Fraud_detection_file=joblib.dump(lg,"Fraud_detection.obj")
Fraud_detection_file
# Out:
# ['Fraud_detection.obj']
