# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
x=df.iloc[:,1:17]
y=df.iloc[:,-17]

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No null values are present in given Dataset

# %% [markdown]
# # EDA Estimation(Data Visulization)

# %%
plt.figure(figsize=(10,5))

sns.pairplot(df)

# %%
sns.boxplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R'>

# %% [markdown]
# max R is lying b/w 650 to 720

# %%
sns.histplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Count'>

# %%
sns.scatterplot(df['W'],df['R'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %% [markdown]
# following graph has the linear relationship b/w W & R

# %%
sns.lineplot(df['W'],df['R'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
sns.kdeplot(df['W'],df['R'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
sns.scatterplot(df['W'],df['AB'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='AB'>

# %% [markdown]
# Data is more baised

# %%
sns.lineplot(df['W'],df['AB'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='AB'>

# %%
sns.scatterplot(df['W'],df['H'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='H'>

# %% [markdown]
# Data is more baised

# %%
sns.scatterplot(df['W'],df['2B'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='2B'>

# %% [markdown]
# this graph is showing that 2B has not much contribution with o/p column

# %%
sns.scatterplot(df['W'],df['3B'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='3B'>

# %%
sns.lineplot(df['W'],df['3B'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='3B'>

# %% [markdown]
# this graph is showing that 3B has not much contribution with o/p column

# %%
sns.scatterplot(df['W'],df['HR'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='HR'>

# %%
sns.scatterplot(df['W'],df['BB'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='BB'>

# %%
sns.scatterplot(df['W'],df['SO'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='SO'>

# %%
sns.lineplot(df['W'],df['SO'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='SO'>

# %% [markdown]
# this graph is showing that SO has not much contribution with o/p column

# %%
sns.scatterplot(df['W'],df['SB'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='SB'>

# %%
sns.scatterplot(df['W'],df['RA'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='RA'>

# %% [markdown]
# it has has -ve Linear realtionship b/w o/p & ERA column

# %%
sns.scatterplot(df['W'],df['ER'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='ER'>

# %% [markdown]
# t has has -ve Linear realtionship b/w o/p & ERcolumn

# %%
sns.scatterplot(df['W'],df['CG'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='CG'>

# %% [markdown]
# both columns are not dependant to each other ,Data is more Baised

# %%
sns.scatterplot(df['W'],df['ERA'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='ERA'>

# %% [markdown]
# it has has -ve Linear realtionship b/w o/p & ERA column

# %%
sns.scatterplot(df['W'],df['SHO'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='SHO'>

# %%
sns.scatterplot(df['W'],df['SV'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='SV'>

# %% [markdown]
# folowing graph has the gd relationship b/w W& SV

# %%
sns.scatterplot(df['W'],df['E'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='E'>

# %%
sns.distplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %% [markdown]
# Above graph is showing that mostly WIN are lying b/w 75 to 90

# %% [markdown]
# # Defining Correlation for given Datasets

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# here we have defined the corr of Label Column with other columns of given dataset

# %%
plt.figure(figsize=(12,7))

sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# This is the graphical representation of Output column with other columns of dataset

# %% [markdown]
# #  Describing the given Datasets

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(round(df.describe()[1:].transpose(),2),annot=True,linecolor='Black',linewidths=.5,fmt='.2f')
plt.title("describe Summary")
plt.xticks(fontsize=18)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # finding outliers present in given dataset

# %%
df.plot(kind='box',layout=(3,8),subplots=True,figsize=(15,8))
# Out:
# W         AxesSubplot(0.125,0.657941;0.0824468x0.222059)
# R      AxesSubplot(0.223936,0.657941;0.0824468x0.222059)
# AB     AxesSubplot(0.322872,0.657941;0.0824468x0.222059)
# H      AxesSubplot(0.421809,0.657941;0.0824468x0.222059)
# 2B     AxesSubplot(0.520745,0.657941;0.0824468x0.222059)
# 3B     AxesSubplot(0.619681,0.657941;0.0824468x0.222059)
# HR     AxesSubplot(0.718617,0.657941;0.0824468x0.222059)
# BB     AxesSubplot(0.817553,0.657941;0.0824468x0.222059)
# SO        AxesSubplot(0.125,0.391471;0.0824468x0.222059)
# SB     AxesSubplot(0.223936,0.391471;0.0824468x0.222059)
# RA     AxesSubplot(0.322872,0.391471;0.0824468x0.222059)
# ER     AxesSubplot(0.421809,0.391471;0.0824468x0.222059)
# ERA    AxesSubplot(0.520745,0.391471;0.0824468x0.222059)
# CG     AxesSubplot(0.619681,0.391471;0.0824468x0.222059)
# SHO    AxesSubplot(0.718617,0.391471;0.0824468x0.222059)
# SV     AxesSubplot(0.817553,0.391471;0.0824468x0.222059)
# ...

# %% [markdown]
# outliers are presendt in given datasets

# %% [markdown]
# # we are using zscore method to determine & for removing these outliers

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))

# %%
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
thresold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(' Old_dataFrame',df.shape)
print('new_dataFrame',df_new.shape)
print("total reduction in row",df.shape[0]-df_new.shape[0])
# Out:
#  Old_dataFrame (30, 17)
# new_dataFrame (29, 17)
# total reduction in row 1

# %%
df_new.shape
# Out:
# (29, 17)

# %%
Data_percentage_loss=(30-29)/30*100

# %%
Data_percentage_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# # Spliting the Data for training & tesing

# %%
x=df_new.iloc[:,1:17]
y=df_new.iloc[:,-17]

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# ...

# %%
x.shape
# Out:
# (29, 16)

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# # Transformimg Data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052227e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800484e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213883e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %%
pd.DataFrame(x).skew()
# Out:
# 0    -0.024842
# 1     0.000000
# 2     0.000000
# 3    -0.052793
# 4    -0.075139
# 5     0.000448
# 6    -0.008572
# 7     0.051530
# 8    -0.009570
# 9    -0.011974
# 10   -0.004988
# 11   -0.000401
# 12   -0.045947
# 13    0.000529
# 14   -0.000925
# 15    0.065585
# dtype: float64

# %% [markdown]
# Now skewness is removed

# %% [markdown]
# # the MIN values & MAX values difference is higher in Describe dataset so use the scaling method to scale the data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052227e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800484e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213883e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB


train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=.22,random_state=42)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,LogisticRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
lr=LinearRegression()

# %%
for i in range(0,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=i)
        lr.fit(train_x,train_y)
        lrpred=lr.predict(test_x)
        print(f"at random_state{i},the training accuracy score is := {r2_score(test_y,lrpred)}")
        print(f"at random_state{i},the testing accuracy is: =   {lr.score(train_x,train_y)}")
# Out:
# at random_state0,the training accuracy score is := 0.5493326935439207
# at random_state0,the testing accuracy is: =   0.9721988993735987
# at random_state1,the training accuracy score is := 0.836846786000726
# at random_state1,the testing accuracy is: =   0.9530846867182348
# at random_state2,the training accuracy score is := 0.3361651835334414
# at random_state2,the testing accuracy is: =   0.948973185944343
# at random_state3,the training accuracy score is := 0.9211876785620988
# at random_state3,the testing accuracy is: =   0.9415620923644433
# at random_state4,the training accuracy score is := 0.7284939349262096
# at random_state4,the testing accuracy is: =   0.9630193905006122
# at random_state5,the training accuracy score is := 0.5877179711445872
# at random_state5,the testing accuracy is: =   0.9641063670889382
# at random_state6,the training accuracy score is := 0.8095098270789232
# at random_state6,the testing accuracy is: =   0.949461590703979
# ...

# %%
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=99)
        lr.fit(train_x,train_y)
        lrpred=lr.predict(test_x)
        print(f"at random_state{99},the training accuracy score is := {r2_score(test_y,lrpred)}")
        print(f"at random_state{99},the testing accuracy is: =   {lr.score(train_x,train_y)}")
# Out:
# at random_state99,the training accuracy score is := 0.9002353649857107
# at random_state99,the testing accuracy is: =   0.9477710279920535

# %% [markdown]
# # Use Lasso & ridge methods for regularization to overcome underfitting & over fitting

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=(j))
    mean_score=cv_score.mean()
    print("at cv(j),mean_accuracy_score is:= {cv_score.mean()}")
# Out:
# at cv(j),mean_accuracy_score is:= {cv_score.mean()}
# at cv(j),mean_accuracy_score is:= {cv_score.mean()}
# at cv(j),mean_accuracy_score is:= {cv_score.mean()}
# at cv(j),mean_accuracy_score is:= {cv_score.mean()}
# at cv(j),mean_accuracy_score is:= {cv_score.mean()}
# at cv(j),mean_accuracy_score is:= {cv_score.mean()}
# at cv(j),mean_accuracy_score is:= {cv_score.mean()}
# at cv(j),mean_accuracy_score is:= {cv_score.mean()}

# %%
    cv_score=cross_val_score(lr,x,y,cv=5)
    mean_score=cv_score.mean()

# %%
mean_score
# Out:
# 0.3761324398565543

# %% [markdown]
# Here in cross validation technique the mean_accuracy score for model is decreasing so the best mean_score is found 37.7% at cv value =5

# %% [markdown]
# # Regularization technique for Linear Model

# %% [markdown]
# Lasso model

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
ls=Lasso()

# %%
Alpha_value={'alpha':[.0001,.001,.01,.1,1,10]}
grid=GridSearchCV(ls,Alpha_value)
grid.fit(train_x,train_y)
print(grid)
print(grid.best_params_)
# Out:
# GridSearchCV(estimator=Lasso(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10]})
# {'alpha': 1}

# %%
ls=Lasso(alpha=.001)
ls.fit(train_x,train_y)
lstrain_score=ls.score(train_x,train_y)
lspred=ls.predict(test_x)

# %%
print(ls.score(train_x,train_y))
print(r2_score(test_y,lspred))
# Out:
# 0.9477647501198947
# 0.9011741836418382

# %% [markdown]
# Ridge model

# %%
rd=Ridge()
Alpha_value={'alpha':[.0001,.001,.01,.1,1,10]}
grid=GridSearchCV(rd,Alpha_value)
grid.fit(train_x,train_y)
print(grid)
print(grid.best_params_)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10]})
# {'alpha': 10}

# %%
rd=Ridge(alpha=10)
rd.fit(train_x,train_y)
rd.score(train_x,train_y)
rdpred=rd.predict(test_x)

# %%
print(rd.score(train_x,train_y))
print(r2_score(test_y,rdpred))
# Out:
# 0.8758692828639391
# 0.8610442148933151

# %% [markdown]
# # Ensemble Technique

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rf=RandomForestRegressor()

# %%
rfparam={'criterion':['mae','mse'],'max_features':["log2","auto","sqrt"]}
grid=GridSearchCV(rf,rfparam)
grid.fit(train_x,train_y)
print(grid)
print(grid.best_params_)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mae', 'mse'],
#                          'max_features': ['log2', 'auto', 'sqrt']})
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf.fit(train_x,train_y)
rfpred=rf.predict(test_x)

# %%
print(r2_score(test_y,rfpred))
# Out:
# 0.6645852512745812

# %%
cv_score=cross_val_score(rf,x,y,cv=4)
print(cv_score.mean())
# Out:
# 0.5204859006265273

# %% [markdown]
# # Prediction for model

# %% [markdown]
# Here we have applied Liner Regression ,Ridge,Lasso,RandomForestRegressor models for finding the better model performance.
# so i got the Lasso model as the best with Model training accuracy=94.77% & Testing Accuracy=90.11%.

# %%
import joblib

# %%
BaseBal_Model=joblib.dump(ls,'BassBAllFile.obj')

# %%
BaseBal_Model
# Out:
# ['BassBAllFile.obj']

# %% [markdown]
# # Now Save the model for final production
