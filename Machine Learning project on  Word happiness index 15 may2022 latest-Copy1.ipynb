# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
sns.scatterplot(df['Region'],df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Freedom'>

# %%
sns.scatterplot(df['Region'],df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Happiness Rank'>

# %%
sns.scatterplot(df['Region'],df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Happiness Score'>

# %%
sns.scatterplot(df['Region'],df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Economy (GDP per Capita)'>

# %%
sns.scatterplot(df['Region'],df['Family'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Family'>

# %%
sns.scatterplot(df['Region'],df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Health (Life Expectancy)'>

# %%
sns.scatterplot(df['Region'],df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Generosity'>

# %%
sns.scatterplot(df['Region'],df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Trust (Government Corruption)'>

# %%
sns.scatterplot(df['Region'],df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(df['Country'],df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(df['Region'],df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Dystopia Residual'>

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
df.corr().value_counts()
# Out:
# Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  Family     Health (Life Expectancy)  Freedom    Trust (Government Corruption)  Generosity  Dystopia Residual
# -0.992105        1.000000        -0.177254        0.780966                  0.740605   0.724200                  0.568211   0.395199                       0.180319    0.530474            1
# -0.785267        0.780966        -0.217651        1.000000                  0.645299   0.816478                  0.370300   0.307885                      -0.010465    0.040059            1
# -0.735613        0.724200        -0.310287        0.816478                  0.531104   1.000000                  0.360477   0.248335                       0.108335    0.018979            1
# -0.733644        0.740605        -0.120728        0.645299                  1.000000   0.531104                  0.441518   0.205605                       0.087513    0.148117            1
# ...

# %%
df.corr()['Dystopia Residual'].sort_values()
# Out:
# Happiness Rank                  -0.521999
# Generosity                      -0.101301
# Trust (Government Corruption)   -0.033105
# Health (Life Expectancy)         0.018979
# Economy (GDP per Capita)         0.040059
# Freedom                          0.062783
# Standard Error                   0.083981
# Family                           0.148117
# Happiness Score                  0.530474
# Dystopia Residual                1.000000
# Name: Dystopia Residual, dtype: float64

# %% [markdown]
# # Finding Correlation using Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,5))
sns.heatmap(df.corr(),annot=True,linecolor="Black",linewidths=0.5,fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outcome for Correlation:-
# 1-happiness rank has 52% -ve correaltionship with Target column.
# 2-Happinesness score has 53% correaltionship with Target column.
# 3-Economy GDP has in 4% correaltionship with Target column.
# 4-Family has in 15% correaltionship with Target column.
# 5-Health has in 2% correaltionship with Target column.
# 6-Freedom has in 6% correaltionship with Target column.
# 7-Trust has in 3% -ve correaltionship with Target column.
# 8-Generosity has in 1% -ve correaltionship with Target column.

# %% [markdown]
# # Describing Datasets:

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(15,5))
sns.heatmap(round(df.describe()[1:].transpose(),2),annot=True,linewidths=2,linecolor="Black",fmt='0.2f')
plt.title("describe summary")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.plot(kind='box',subplots=True,layout=(2,10),figsize=(20,20))
# Out:
# Happiness Rank                      AxesSubplot(0.125,0.536818;0.065678x0.343182)
# Happiness Score                  AxesSubplot(0.203814,0.536818;0.065678x0.343182)
# Standard Error                   AxesSubplot(0.282627,0.536818;0.065678x0.343182)
# Economy (GDP per Capita)         AxesSubplot(0.361441,0.536818;0.065678x0.343182)
# Family                           AxesSubplot(0.440254,0.536818;0.065678x0.343182)
# Health (Life Expectancy)         AxesSubplot(0.519068,0.536818;0.065678x0.343182)
# Freedom                          AxesSubplot(0.597881,0.536818;0.065678x0.343182)
# Trust (Government Corruption)    AxesSubplot(0.676695,0.536818;0.065678x0.343182)
# Generosity                       AxesSubplot(0.755508,0.536818;0.065678x0.343182)
# Dystopia Residual                AxesSubplot(0.834322,0.536818;0.065678x0.343182)
# dtype: object

# %% [markdown]
# # Outliers are present in above graphical data
# 1-std devaition coulmn
# 2-Government corruption
# 3-Generosity

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # skewness are presenet in following column:
#     1-standard Error
#     2-trust(Government corruption)

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# # given graphs are showing that normal curve passing through by missing some blocks .so data is not in normilized form.

# %% [markdown]
# # the normal distribution shows that data is skewed

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df=df.drop(['Country','Region'],axis=1)
df
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))

# %%
z.shape
# Out:
# (158, 10)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 9

# %%
z.iloc[27]
# Out:
# Happiness Rank                   1.129016
# Happiness Score                  1.082256
# Standard Error                   0.859197
# Economy (GDP per Capita)         2.101026
# Family                           0.322476
# Health (Life Expectancy)         0.678336
# Freedom                          1.409878
# Trust (Government Corruption)    3.164619
# Generosity                       0.700286
# Dystopia Residual                0.982677
# Name: 27, dtype: float64

# %%
df_new=df[(z<3).all(axis=1)]
print("Old_Datframe",df.shape)
print("new_Dataframe",df_new.shape)
print("Total_dropped_Rows",df.shape[0]-df_new.shape[0])
# Out:
# Old_Datframe (158, 10)
# new_Dataframe (149, 10)
# Total_dropped_Rows 9

# %% [markdown]
# # Percentage Data Loss

# %%
loss_percentage=(158-149)/158*100
loss_percentage
# Out:
# 5.69620253164557

# %% [markdown]
# # since the nodel has 2 variable so we will use binary classification model

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %%
x
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 150             151            3.655         0.05141
# 151             152            3.587         0.04324
# 152             153            3.575         0.03084
# 154             155            3.340         0.03656
# 156             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
y
# Out:
# 0      2.51738
# 1      2.70201
# 2      2.49204
# 3      2.46531
# 4      2.45176
#         ...
# 150    1.41723
# 151    1.46494
# 152    1.95210
# 154    1.63328
# 156    1.83302
# Name: Dystopia Residual, Length: 149, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,random_state=28,test_size=0.20)

# %%
x_train
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 21               22            6.853         0.05335
# 149             150            3.656         0.03590
# 95               96            4.949         0.06913
# 28               29            6.575         0.03512
# 80               81            5.194         0.03726
# ..              ...              ...             ...
# 3                 4            7.522         0.03880
# 33               34            6.455         0.03557
# 22               23            6.810         0.06476
# 5                 6            7.406         0.03140
# 1                 2            7.561         0.04884
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 21                    1.36011  1.08182                   0.76276  0.63274
# 149                   0.17417  0.46475                   0.24009  0.37725
# 95                    0.83223  0.91916                   0.79081  0.09245
# ...

# %%
y_train
# Out:
# 21     2.47489
# 149    1.99172
# 95     2.06367
# 28     2.21126
# 80     3.10709
#         ...
# 3      2.46531
# 33     2.31945
# 22     3.19131
# 5      2.61955
# 1      2.70201
# Name: Dystopia Residual, Length: 119, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
lm=LinearRegression()

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,random_state=28,test_size=0.20)

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.score(x_train,y_train)
# Out:
# 0.9999997358837975

# %%
lm.coef_
# Out:
# array([ 7.55597292e-06,  1.00032454e+00,  9.74315469e-04, -1.00013803e+00,
#        -1.00003882e+00, -9.99939642e-01, -9.99619620e-01, -1.00003848e+00,
#        -1.00031155e+00])

# %%
lm.intercept_
# Out:
# -0.0023346445103076263

# %%
pred=lm.predict(x_test)

# %%
print("predicted value and actual value",pred,y_test)
# Out:
# predicted value and actual value [2.8483057  1.6816193  2.63447773 2.50961427 2.24191241 2.79886717
#  1.95081827 1.86966444 2.75459346 1.64826067 1.84416878 3.26051543
#  2.18858747 2.24708035 0.99848514 2.82362877 2.11820288 1.46181024
#  1.95249568 1.59855413 2.51754467 2.32303596 2.44682851 1.86416071
#  2.23229926 3.10712129 2.51775136 1.42785649 2.26646427 1.61611108] 24     2.84848
# 138    1.68135
# 84     2.63430
# 14     2.51011
# 118    2.24173
# 96     2.79832
# 132    1.95071
# 69     1.86984
# 61     2.75414
# 36     1.64880
# 104    1.84408
# 15     3.26001
# 52     2.18896
# 53     2.24729
# 142    0.99895
# 50     2.82334
# 123    2.11773
# 127    1.46181
# 152    1.95210
# 65     1.59888
# 0      2.51738
# 37     2.32323
# 55     2.44649
# 73     1.86399
# 76     2.23270
# 51     3.10712
# 108    2.51767
# 140    1.42766
# 9      2.26646
# 54     1.61583
# Name: Dystopia Residual, dtype: float64

# %%
mean_squared_error(y_test,pred)
# Out:
# 9.924092594961234e-08

# %%
mean_absolute_error(y_test,pred)
# Out:
# 0.00026937060295103193

# %%
print("mean square root error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# mean square root error 0.0003150252782708276

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,pred))
# Out:
# 0.9999996425390566
