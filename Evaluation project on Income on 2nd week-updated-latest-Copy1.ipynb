# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv")

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# there is no non value present in above dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
plt.figure(figsize=(15,10))

sns.scatterplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# above graph is showing only 6 numeric columns in given Dataset .

# %%
sns.boxplot(df['Age'],df['Sex'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %% [markdown]
# Female are showing between25 yrs to 45 yrs & male age are lying between 30 yrs to 50 yrs.

# %%
sns.catplot(x='Income',y='Age',hue='Sex',kind='box',data=df)

# %% [markdown]
# Above graph is showing the income of Male & Female W.R.T Age which are >50K or <50K.

# %%
sns.displot(df['Age'])

# %% [markdown]
# above graph is showing age which lying netween 25 to 50yrs.

# %%
sns.histplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# most of people have age between 20 to 45 yrs

# %%
sns.histplot(df['Income'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Count'>

# %%
sns.countplot(df['Income'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# approx 24000 peole have the income less than 50K ann approx 8000 people have the income>50K

# %%
plt.figure(figsize=(15,10))
sns.catplot(data=df)

# %%
sns.lineplot(df['Age'],df['Fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fnlwgt'>

# %%
sns.lineplot(df['Age'],df['Education_num'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Education_num'>

# %%
sns.lineplot(df['Age'],df['Income'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>

# %%
sns.kdeplot(df['Age'],df['Education_num'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Education_num'>

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
en=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=en.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0   83311        9.0             13             2.0
# 1       38        4.0  215646       11.0              9             0.0
# 2       53        4.0  234721        1.0              7             2.0
# 3       28        4.0  338409        9.0             13             2.0
# 4       37        4.0  284582       12.0             14             2.0
# ...    ...        ...     ...        ...            ...             ...
# 32555   27        4.0  257302        7.0             12             2.0
# 32556   40        4.0  154374       11.0              9             2.0
# 32557   58        4.0  151910       11.0              9             6.0
# 32558   22        4.0  201490       11.0              9             4.0
# 32559   52        5.0  287927       11.0              9             2.0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0             4.0           0.0   4.0  1.0             0             0
# 1             6.0           1.0   4.0  1.0             0             0
# 2             6.0           0.0   2.0  1.0             0             0
# 3            10.0           5.0   2.0  0.0             0             0
# 4             4.0           5.0   4.0  0.0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32555        13.0           5.0   4.0  0.0             0             0
# 32556         7.0           0.0   4.0  1.0             0             0
# 32557         1.0           4.0   4.0  0.0             0             0
# 32558         1.0           3.0   4.0  1.0             0             0
# 32559         4.0           5.0   4.0  0.0         15024             0
#
#        Hours_per_week  Native_country  Income
# 0                  13            39.0     0.0
# 1                  40            39.0     0.0
# 2                  40            39.0     0.0
# 3                  40             5.0     0.0
# 4                  40            39.0     0.0
# ...               ...             ...     ...
# 32555              38            39.0     0.0
# 32556              40            39.0     1.0
# 32557              40            39.0     0.0
# 32558              20            39.0     0.0
# 32559              40            39.0     1.0
#
# [32560 rows x 15 columns]

# %% [markdown]
# here we have used OrdinalEncoder to convert the object value into int value,now dataframe consists only int value.

# %% [markdown]
# # Defining Correlation in given Dataset

# %%
df.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.003786 -0.076646  -0.010508       0.036527
# Workclass       0.003786   1.000000 -0.016587   0.023537       0.052015
# Fnlwgt         -0.076646  -0.016587  1.000000  -0.028156      -0.043159
# Education      -0.010508   0.023537 -0.028156   1.000000       0.359172
# Education_num   0.036527   0.052015 -0.043159   0.359172       1.000000
# Marital_status -0.266292  -0.064798  0.028184  -0.038398      -0.069338
# Occupation     -0.020946   0.255004  0.001554  -0.021274       0.109748
# Relationship   -0.263698  -0.090449  0.008922  -0.010879      -0.094145
# Race            0.028718   0.049720 -0.021278   0.014135       0.031825
# Sex             0.088832   0.095942  0.026882  -0.027349       0.012256
# Capital_gain    0.077674   0.033828  0.000437   0.030047       0.122627
# Capital_loss    0.057775   0.012231 -0.010259   0.016744       0.079932
# Hours_per_week  0.068756   0.138974 -0.018770   0.055510       0.148127
# Native_country -0.001151  -0.007710 -0.051957   0.064291       0.050831
# Income          0.234039   0.051645 -0.009481   0.079311       0.335182
#
#                 Marital_status  Occupation  Relationship      Race       Sex  \
# Age                  -0.266292   -0.020946     -0.263698  0.028718  0.088832
# Workclass            -0.064798    0.255004     -0.090449  0.049720  0.095942
# Fnlwgt                0.028184    0.001554      0.008922 -0.021278  0.026882
# Education            -0.038398   -0.021274     -0.010879  0.014135 -0.027349
# Education_num        -0.069338    0.109748     -0.094145  0.031825  0.012256
# Marital_status        1.000000   -0.009617      0.185461 -0.068025 -0.129337
# Occupation           -0.009617    1.000000     -0.075620  0.006779  0.080328
# Relationship          0.185461   -0.075620      1.000000 -0.116052 -0.582453
# Race                 -0.068025    0.006779     -0.116052  1.000000  0.087197
# Sex                  -0.129337    0.080328     -0.582453  0.087197  1.000000
# Capital_gain         -0.043398    0.025511     -0.057918  0.011143  0.048477
# Capital_loss         -0.034182    0.017979     -0.061064  0.018902  0.045572
# Hours_per_week       -0.190521    0.080384     -0.248975  0.041910  0.229312
# Native_country       -0.023827   -0.012532     -0.005504  0.137849 -0.008125
# Income               -0.199295    0.075448     -0.250924  0.071853  0.215995
#
#                 Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# Age                 0.077674      0.057775        0.068756       -0.001151
# Workclass           0.033828      0.012231        0.138974       -0.007710
# Fnlwgt              0.000437     -0.010259       -0.018770       -0.051957
# Education           0.030047      0.016744        0.055510        0.064291
# Education_num       0.122627      0.079932        0.148127        0.050831
# Marital_status     -0.043398     -0.034182       -0.190521       -0.023827
# Occupation          0.025511      0.017979        0.080384       -0.012532
# Relationship       -0.057918     -0.061064       -0.248975       -0.005504
# Race                0.011143      0.018902        0.041910        0.137849
# Sex                 0.048477      0.045572        0.229312       -0.008125
# Capital_gain        1.000000     -0.031614        0.078409       -0.001984
# Capital_loss       -0.031614      1.000000        0.054256        0.000420
# Hours_per_week      0.078409      0.054256        1.000000       -0.002671
# Native_country     -0.001984      0.000420       -0.002671        1.000000
# Income              0.223333      0.150523        0.229690        0.015845
#
#                   Income
# Age             0.234039
# Workclass       0.051645
# Fnlwgt         -0.009481
# Education       0.079311
# Education_num   0.335182
# Marital_status -0.199295
# Occupation      0.075448
# Relationship   -0.250924
# Race            0.071853
# Sex             0.215995
# Capital_gain    0.223333
# Capital_loss    0.150523
# Hours_per_week  0.229690
# Native_country  0.015845
# Income          1.000000

# %%
df.corr()['Income'].sort_values()
# Out:
# Relationship     -0.250924
# Marital_status   -0.199295
# Fnlwgt           -0.009481
# Native_country    0.015845
# Workclass         0.051645
# Race              0.071853
# Occupation        0.075448
# Education         0.079311
# Capital_loss      0.150523
# Sex               0.215995
# Capital_gain      0.223333
# Hours_per_week    0.229690
# Age               0.234039
# Education_num     0.335182
# Income            1.000000
# Name: Income, dtype: float64

# %% [markdown]
# here we have defined the corr of Label Column with other columns of given dataset

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor='Black',fmt='.4f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# This is the graphical representation of Output column with other columns of dataset

# %% [markdown]
# # describing  the given Dataset

# %%
df.describe()
# Out:
#                 Age     Workclass        Fnlwgt     Education  Education_num  \
# count  32560.000000  32560.000000  3.256000e+04  32560.000000   32560.000000
# mean      38.581634      3.868796  1.897818e+05     10.298249      10.080590
# std       13.640642      1.455879  1.055498e+05      3.870317       2.572709
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      4.000000  1.178315e+05      9.000000       9.000000
# 50%       37.000000      4.000000  1.783630e+05     11.000000      10.000000
# 75%       48.000000      4.000000  2.370545e+05     12.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        Marital_status    Occupation  Relationship          Race           Sex  \
# count    32560.000000  32560.000000  32560.000000  32560.000000  32560.000000
# mean         2.611794      6.572912      1.446376      3.665848      0.669195
# std          1.506225      4.228809      1.606794      0.848817      0.470510
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%          2.000000      3.000000      0.000000      4.000000      0.000000
# 50%          2.000000      7.000000      1.000000      4.000000      1.000000
# 75%          4.000000     10.000000      3.000000      4.000000      1.000000
# max          6.000000     14.000000      5.000000      4.000000      1.000000
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# count  32560.000000  32560.000000    32560.000000    32560.000000
# mean    1077.615172     87.306511       40.437469       36.718796
# std     7385.402999    402.966116       12.347618        7.823892
# min        0.000000      0.000000        1.000000        0.000000
# 25%        0.000000      0.000000       40.000000       39.000000
# 50%        0.000000      0.000000       40.000000       39.000000
# 75%        0.000000      0.000000       45.000000       39.000000
# max    99999.000000   4356.000000       99.000000       41.000000
#
#              Income
# count  32560.000000
# mean       0.240817
# std        0.427586
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
sns.heatmap(round(df.describe()[1:].transpose(),2),annot=True,linewidths=.5,linecolor='Black',fmt='.2f')
plt.title("describe summary")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # Defining Outliers for Given Dataset

# %%
df.plot(kind='box',subplots=True,layout=(3,6),figsize=(15,8))
# Out:
# Age                  AxesSubplot(0.125,0.657941;0.110714x0.222059)
# Workclass         AxesSubplot(0.257857,0.657941;0.110714x0.222059)
# Fnlwgt            AxesSubplot(0.390714,0.657941;0.110714x0.222059)
# Education         AxesSubplot(0.523571,0.657941;0.110714x0.222059)
# Education_num     AxesSubplot(0.656429,0.657941;0.110714x0.222059)
# Marital_status    AxesSubplot(0.789286,0.657941;0.110714x0.222059)
# Occupation           AxesSubplot(0.125,0.391471;0.110714x0.222059)
# Relationship      AxesSubplot(0.257857,0.391471;0.110714x0.222059)
# Race              AxesSubplot(0.390714,0.391471;0.110714x0.222059)
# Sex               AxesSubplot(0.523571,0.391471;0.110714x0.222059)
# Capital_gain      AxesSubplot(0.656429,0.391471;0.110714x0.222059)
# Capital_loss      AxesSubplot(0.789286,0.391471;0.110714x0.222059)
# Hours_per_week          AxesSubplot(0.125,0.125;0.110714x0.222059)
# Native_country       AxesSubplot(0.257857,0.125;0.110714x0.222059)
# Income               AxesSubplot(0.390714,0.125;0.110714x0.222059)
# dtype: object

# %% [markdown]
# given plot is showing that outliers are present in Dataset

# %% [markdown]
# # we are using zscore method to determine & for removing these outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
z
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.837097   1.463883  1.008742   0.335443       1.134779
# 1      0.042640   0.090121  0.245046   0.181319       0.420027
# 2      1.057031   0.090121  0.425770   2.402489       1.197429
# 3      0.775755   0.090121  1.408146   0.335443       1.134779
# 4      0.115952   0.090121  0.898170   0.439700       1.523480
# ...         ...        ...       ...        ...            ...
# 32555  0.849066   0.090121  0.639710   0.852204       0.746077
# 32556  0.103982   0.090121  0.335466   0.181319       0.420027
# 32557  1.423589   0.090121  0.358811   0.181319       0.420027
# 32558  1.215624   0.090121  0.110927   0.181319       0.420027
# 32559  0.983720   0.777002  0.929862   0.181319       0.420027
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0            0.406183    0.608434      0.900177  0.393675  0.703087
# 1            1.734026    0.135480      0.277810  0.393675  0.703087
# 2            0.406183    0.135480      0.900177  1.962583  0.703087
# 3            0.406183    0.810427      2.211658  1.962583  1.422298
# 4            0.406183    0.608434      2.211658  0.393675  1.422298
# ...               ...         ...           ...       ...       ...
# 32555        0.406183    1.519858      2.211658  0.393675  1.422298
# 32556        0.406183    0.100997      0.900177  0.393675  0.703087
# 32557        2.249503    1.317864      1.589291  0.393675  1.422298
# 32558        0.921660    1.317864      0.966924  0.393675  0.703087
# 32559        0.406183    0.608434      2.211658  0.393675  1.422298
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country    Income
# 0          0.145914      0.216663        2.222120        0.291573  0.563210
# 1          0.145914      0.216663        0.035430        0.291573  0.563210
# 2          0.145914      0.216663        0.035430        0.291573  0.563210
# 3          0.145914      0.216663        0.035430        4.054157  0.563210
# 4          0.145914      0.216663        0.035430        0.291573  0.563210
# ...             ...           ...             ...             ...       ...
# 32555      0.145914      0.216663        0.197407        0.291573  0.563210
# 32556      0.145914      0.216663        0.035430        0.291573  1.775537
# 32557      0.145914      0.216663        0.035430        0.291573  0.563210
# 32558      0.145914      0.216663        1.655200        0.291573  0.563210
# 32559      1.888401      0.216663        0.035430        0.291573  1.775537
#
# [32560 rows x 15 columns]

# %%
thresold=3
print(np.where(z>3))
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552], dtype=int64), array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
print('Old_dataframe',df.shape)
print('new_dataframe',df_new.shape)
print("reduction in rows",df.shape[0]-df_new.shape[0])
# Out:
# Old_dataframe (32560, 15)
# new_dataframe (27417, 15)
# reduction in rows 5143

# %%
Percentage_dataloss=(7043-6361)/7043*100

# %%
Percentage_dataloss
# Out:
# 9.683373562402386

# %%
x=df_new.drop('Income',axis=1)

# %%
x
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0   83311        9.0             13             2.0
# 1       38        4.0  215646       11.0              9             0.0
# 2       53        4.0  234721        1.0              7             2.0
# 4       37        4.0  284582       12.0             14             2.0
# 5       49        4.0  160187        6.0              5             3.0
# ...    ...        ...     ...        ...            ...             ...
# 32555   27        4.0  257302        7.0             12             2.0
# 32556   40        4.0  154374       11.0              9             2.0
# 32557   58        4.0  151910       11.0              9             6.0
# 32558   22        4.0  201490       11.0              9             4.0
# 32559   52        5.0  287927       11.0              9             2.0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0             4.0           0.0   4.0  1.0             0             0
# 1             6.0           1.0   4.0  1.0             0             0
# 2             6.0           0.0   2.0  1.0             0             0
# 4             4.0           5.0   4.0  0.0             0             0
# 5             8.0           1.0   2.0  0.0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32555        13.0           5.0   4.0  0.0             0             0
# 32556         7.0           0.0   4.0  1.0             0             0
# 32557         1.0           4.0   4.0  0.0             0             0
# 32558         1.0           3.0   4.0  1.0             0             0
# 32559         4.0           5.0   4.0  0.0         15024             0
#
#        Hours_per_week  Native_country
# 0                  13            39.0
# 1                  40            39.0
# 2                  40            39.0
# 4                  40            39.0
# 5                  16            23.0
# ...               ...             ...
# 32555              38            39.0
# 32556              40            39.0
# 32557              40            39.0
# 32558              20            39.0
# 32559              40            39.0
#
# [27417 rows x 14 columns]

# %%
y=df_new['Income']

# %%
y
# Out:
# 0        0.0
# 1        0.0
# 2        0.0
# 4        0.0
# 5        0.0
#         ...
# 32555    0.0
# 32556    1.0
# 32557    0.0
# 32558    0.0
# 32559    1.0
# Name: Income, Length: 27417, dtype: float64

# %% [markdown]
# # Transformimg Data to remove skewness

# %% [markdown]
# Using the power transforming method to remove Skewness present in the given dataset

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 0.92387928,  1.65209239, -1.12465326, ..., -0.04054646,
#         -2.21338681,  0.17213488],
#        [ 0.12850238,  0.01669779,  0.41302315, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        [ 1.09846907,  0.01669779,  0.59312735, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        ...,
#        [ 1.37259752,  0.01669779, -0.24852704, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        [-1.32725084,  0.01669779,  0.27467596, ..., -0.04054646,
#         -1.71987004,  0.17213488],
#        [ 1.04117247,  0.80120487,  1.06334322, ..., -0.04054646,
#         -0.03813668,  0.17213488]])

# %% [markdown]
# the MIN values & MAX values difference is higher in Describe dataset so use the scaling method to scale the data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 0.92387928,  1.65209239, -1.12465326, ..., -0.04054646,
#         -2.21338681,  0.17213488],
#        [ 0.12850238,  0.01669779,  0.41302315, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        [ 1.09846907,  0.01669779,  0.59312735, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        ...,
#        [ 1.37259752,  0.01669779, -0.24852704, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        [-1.32725084,  0.01669779,  0.27467596, ..., -0.04054646,
#         -1.71987004,  0.17213488],
#        [ 1.04117247,  0.80120487,  1.06334322, ..., -0.04054646,
#         -0.03813668,  0.17213488]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
lg=LogisticRegression()

# %%
for i in range(0,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=i)
        lg.fit(train_x,train_y)
        lrpred=lg.predict(test_x)
        print(f"at random_state{i},the testing accuracy score is := {accuracy_score(test_y,lrpred)}")
        print(f"at random_state{i},the training accuracy is: =   {lg.score(train_x,train_y)}")
# Out:
# at random_state0,the testing accuracy score is := 0.8318745441283735
# at random_state0,the training accuracy is: =   0.8272010212921169
# at random_state1,the testing accuracy score is := 0.8316921954777534
# at random_state1,the training accuracy is: =   0.8280672958555602
# at random_state2,the testing accuracy score is := 0.8342450765864332
# at random_state2,the training accuracy is: =   0.8267906807094333
# at random_state3,the testing accuracy score is := 0.8293216630196937
# at random_state3,the training accuracy is: =   0.8291159440113072
# at random_state4,the testing accuracy score is := 0.8276805251641138
# at random_state4,the training accuracy is: =   0.8292071308074591
# at random_state5,the testing accuracy score is := 0.825674690007294
# at random_state5,the training accuracy is: =   0.8288879770209274
# at random_state6,the testing accuracy score is := 0.8264040846097739
# at random_state6,the training accuracy is: =   0.8285232298363197
# at random_state7,the testing accuracy score is := 0.8326039387308534
# at random_state7,the training accuracy is: =   0.8283864496420918
# at random_state8,the testing accuracy score is := 0.8274981765134938
# at random_state8,the training accuracy is: =   0.829298317603611
# at random_state9,the testing accuracy score is := 0.8309628008752735
# at random_state9,the training accuracy is: =   0.828112889253636
# at random_state10,the testing accuracy score is := 0.8214806710430342
# at random_state10,the training accuracy is: =   0.8301189987689782
# at random_state11,the testing accuracy score is := 0.8273158278628738
# at random_state11,the training accuracy is: =   0.8294350977978389
# at random_state12,the testing accuracy score is := 0.8254923413566739
# at random_state12,the training accuracy is: =   0.8297542515843706
# at random_state13,the testing accuracy score is := 0.824945295404814
# at random_state13,the training accuracy is: =   0.8302101855651302
# at random_state14,the testing accuracy score is := 0.824033552151714
# at random_state14,the training accuracy is: =   0.8303013723612821
# at random_state15,the testing accuracy score is := 0.825309992706054
# at random_state15,the training accuracy is: =   0.8301189987689782
# at random_state16,the testing accuracy score is := 0.8260393873085339
# at random_state16,the training accuracy is: =   0.8297542515843706
# at random_state17,the testing accuracy score is := 0.8254923413566739
# at random_state17,the training accuracy is: =   0.8302101855651302
# at random_state18,the testing accuracy score is := 0.8271334792122538
# at random_state18,the training accuracy is: =   0.8286144166324716
# at random_state19,the testing accuracy score is := 0.8172866520787746
# at random_state19,the training accuracy is: =   0.8316235809054849
# at random_state20,the testing accuracy score is := 0.8274981765134938
# at random_state20,the training accuracy is: =   0.8296174713901427
# at random_state21,the testing accuracy score is := 0.8254923413566739
# at random_state21,the training accuracy is: =   0.8292527242055351
# at random_state22,the testing accuracy score is := 0.8284099197665937
# at random_state22,the training accuracy is: =   0.8291159440113072
# at random_state23,the testing accuracy score is := 0.8335156819839533
# at random_state23,the training accuracy is: =   0.8275657684767246
# at random_state24,the testing accuracy score is := 0.8267687819110139
# at random_state24,the training accuracy is: =   0.8292527242055351
# at random_state25,the testing accuracy score is := 0.8295040116703136
# at random_state25,the training accuracy is: =   0.8282952628459399
# at random_state26,the testing accuracy score is := 0.836797957695113
# at random_state26,the training accuracy is: =   0.8276113618748006
# at random_state27,the testing accuracy score is := 0.8309628008752735
# at random_state27,the training accuracy is: =   0.8285688232343956
# at random_state28,the testing accuracy score is := 0.8196571845368344
# at random_state28,the training accuracy is: =   0.8306205261478138
# at random_state29,the testing accuracy score is := 0.8234865061998541
# at random_state29,the training accuracy is: =   0.8297998449824465
# at random_state30,the testing accuracy score is := 0.8260393873085339
# at random_state30,the training accuracy is: =   0.8292071308074591
# at random_state31,the testing accuracy score is := 0.825309992706054
# at random_state31,the training accuracy is: =   0.8298910317785985
# at random_state32,the testing accuracy score is := 0.8298687089715536
# at random_state32,the training accuracy is: =   0.8287056034286235
# at random_state33,the testing accuracy score is := 0.8276805251641138
# at random_state33,the training accuracy is: =   0.8287967902247755
# at random_state34,the testing accuracy score is := 0.8225747629467542
# at random_state34,the training accuracy is: =   0.8298910317785985
# at random_state35,the testing accuracy score is := 0.8331509846827133
# at random_state35,the training accuracy is: =   0.8274745816805726
# at random_state36,the testing accuracy score is := 0.8295040116703136
# at random_state36,the training accuracy is: =   0.8289335704190033
# at random_state37,the testing accuracy score is := 0.8397155361050328
# at random_state37,the training accuracy is: =   0.8265627137190534
# at random_state38,the testing accuracy score is := 0.8238512035010941
# at random_state38,the training accuracy is: =   0.8299366251766744
# at random_state39,the testing accuracy score is := 0.8329686360320934
# at random_state39,the training accuracy is: =   0.8278393288651803
# at random_state40,the testing accuracy score is := 0.8227571115973742
# at random_state40,the training accuracy is: =   0.8300278119728264
# at random_state41,the testing accuracy score is := 0.8357038657913931
# at random_state41,the training accuracy is: =   0.8265171203209776
# at random_state42,the testing accuracy score is := 0.8280452224653537
# at random_state42,the training accuracy is: =   0.8296630647882187
# at random_state43,the testing accuracy score is := 0.8291393143690736
# at random_state43,the training accuracy is: =   0.8287511968266995
# at random_state44,the testing accuracy score is := 0.825674690007294
# at random_state44,the training accuracy is: =   0.8294806911959148
# at random_state45,the testing accuracy score is := 0.825127644055434
# at random_state45,the training accuracy is: =   0.8297998449824465
# at random_state46,the testing accuracy score is := 0.8322392414296135
# at random_state46,the training accuracy is: =   0.8279761090594082
# at random_state47,the testing accuracy score is := 0.8258570386579139
# at random_state47,the training accuracy is: =   0.8298454383805225
# at random_state48,the testing accuracy score is := 0.8347921225382933
# at random_state48,the training accuracy is: =   0.8273833948844207
# at random_state49,the testing accuracy score is := 0.8331509846827133
# at random_state49,the training accuracy is: =   0.8272466146901929
# at random_state50,the testing accuracy score is := 0.8233041575492341
# at random_state50,the training accuracy is: =   0.8303013723612821
# at random_state51,the testing accuracy score is := 0.824762946754194
# at random_state51,the training accuracy is: =   0.8292527242055351
# at random_state52,the testing accuracy score is := 0.8351568198395332
# at random_state52,the training accuracy is: =   0.8276569552728765
# at random_state53,the testing accuracy score is := 0.8304157549234136
# at random_state53,the training accuracy is: =   0.8278393288651803
# at random_state54,the testing accuracy score is := 0.8216630196936543
# at random_state54,the training accuracy is: =   0.8298454383805225
# at random_state55,the testing accuracy score is := 0.8309628008752735
# at random_state55,the training accuracy is: =   0.8282952628459399
# at random_state56,the testing accuracy score is := 0.8316921954777534
# at random_state56,the training accuracy is: =   0.8284776364382438
# at random_state57,the testing accuracy score is := 0.8278628738147338
# at random_state57,the training accuracy is: =   0.8282952628459399
# at random_state58,the testing accuracy score is := 0.8269511305616338
# at random_state58,the training accuracy is: =   0.8292527242055351
# at random_state59,the testing accuracy score is := 0.8171043034281547
# at random_state59,the training accuracy is: =   0.8320795148862444
# at random_state60,the testing accuracy score is := 0.8302334062727936
# at random_state60,the training accuracy is: =   0.828204076049788
# at random_state61,the testing accuracy score is := 0.8309628008752735
# at random_state61,the training accuracy is: =   0.8284320430401678
# at random_state62,the testing accuracy score is := 0.8264040846097739
# at random_state62,the training accuracy is: =   0.8288423836228515
# at random_state63,the testing accuracy score is := 0.8369803063457331
# at random_state63,the training accuracy is: =   0.8266539005152054
# at random_state64,the testing accuracy score is := 0.8202042304886944
# at random_state64,the training accuracy is: =   0.8316235809054849
# at random_state65,the testing accuracy score is := 0.8282275711159738
# at random_state65,the training accuracy is: =   0.8286600100305476
# at random_state66,the testing accuracy score is := 0.8305981035740335
# at random_state66,the training accuracy is: =   0.8290703506132312
# at random_state67,the testing accuracy score is := 0.8194748358862144
# at random_state67,the training accuracy is: =   0.8309852733324214
# at random_state68,the testing accuracy score is := 0.8231218088986142
# at random_state68,the training accuracy is: =   0.8299822185747504
# at random_state69,the testing accuracy score is := 0.8220277169948942
# at random_state69,the training accuracy is: =   0.830392559157434
# at random_state70,the testing accuracy score is := 0.8269511305616338
# at random_state70,the training accuracy is: =   0.8292071308074591
# at random_state71,the testing accuracy score is := 0.8280452224653537
# at random_state71,the training accuracy is: =   0.8288423836228515
# at random_state72,the testing accuracy score is := 0.8344274252370533
# at random_state72,the training accuracy is: =   0.8276569552728765
# at random_state73,the testing accuracy score is := 0.8313274981765135
# at random_state73,the training accuracy is: =   0.8282952628459399
# at random_state74,the testing accuracy score is := 0.8274981765134938
# at random_state74,the training accuracy is: =   0.8283864496420918
# at random_state75,the testing accuracy score is := 0.837527352297593
# at random_state75,the training accuracy is: =   0.8268362741075093
# at random_state76,the testing accuracy score is := 0.8276805251641138
# at random_state76,the training accuracy is: =   0.8292527242055351
# at random_state77,the testing accuracy score is := 0.837709700948213
# at random_state77,the training accuracy is: =   0.8261523731363698
# at random_state78,the testing accuracy score is := 0.837527352297593
# at random_state78,the training accuracy is: =   0.827155427894041
# at random_state79,the testing accuracy score is := 0.8324215900802334
# at random_state79,the training accuracy is: =   0.8277025486709525
# at random_state80,the testing accuracy score is := 0.8342450765864332
# at random_state80,the training accuracy is: =   0.8275657684767246
# at random_state81,the testing accuracy score is := 0.8404449307075128
# at random_state81,the training accuracy is: =   0.8267450873113573
# at random_state82,the testing accuracy score is := 0.824033552151714
# at random_state82,the training accuracy is: =   0.83043815255551
# at random_state83,the testing accuracy score is := 0.8234865061998541
# at random_state83,the training accuracy is: =   0.829298317603611
# at random_state84,the testing accuracy score is := 0.8329686360320934
# at random_state84,the training accuracy is: =   0.8279761090594082
# at random_state85,the testing accuracy score is := 0.8360685630926331
# at random_state85,the training accuracy is: =   0.827018647699813
# at random_state86,the testing accuracy score is := 0.8260393873085339
# at random_state86,the training accuracy is: =   0.8292527242055351
# at random_state87,the testing accuracy score is := 0.8227571115973742
# at random_state87,the training accuracy is: =   0.8300278119728264
# at random_state88,the testing accuracy score is := 0.824945295404814
# at random_state88,the training accuracy is: =   0.8298910317785985
# at random_state89,the testing accuracy score is := 0.8346097738876732
# at random_state89,the training accuracy is: =   0.8268818675055852
# at random_state90,the testing accuracy score is := 0.8322392414296135
# at random_state90,the training accuracy is: =   0.8279761090594082
# at random_state91,the testing accuracy score is := 0.8198395331874544
# at random_state91,the training accuracy is: =   0.8311220535266494
# at random_state92,the testing accuracy score is := 0.8181983953318746
# at random_state92,the training accuracy is: =   0.8308940865362695
# at random_state93,the testing accuracy score is := 0.825127644055434
# at random_state93,the training accuracy is: =   0.8301189987689782
# at random_state94,the testing accuracy score is := 0.8340627279358133
# at random_state94,the training accuracy is: =   0.8274745816805726
# at random_state95,the testing accuracy score is := 0.8242159008023341
# at random_state95,the training accuracy is: =   0.8294806911959148
# at random_state96,the testing accuracy score is := 0.8264040846097739
# at random_state96,the training accuracy is: =   0.8290703506132312
# at random_state97,the testing accuracy score is := 0.8313274981765135
# at random_state97,the training accuracy is: =   0.8279761090594082
# at random_state98,the testing accuracy score is := 0.8234865061998541
# at random_state98,the training accuracy is: =   0.8302557789632061
# at random_state99,the testing accuracy score is := 0.8329686360320934
# at random_state99,the training accuracy is: =   0.828204076049788

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
lg=LogisticRegression()

# %%
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=44)
        lg.fit(train_x,train_y)
        lrpred=lg.predict(test_x)
        print(f"at random_state{44},the testing accuracy score is := {accuracy_score(test_y,lrpred)}")
        print(f"at random_state{44},the training accuracy is: =   {lg.score(train_x,train_y)}")
# Out:
# at random_state44,the testing accuracy score is := 0.825674690007294
# at random_state44,the training accuracy is: =   0.8294806911959148

# %% [markdown]
# # AUC & ROC Curve

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=lg.predict_proba(test_x)[:,1]

# %%
y_pred_prob
# Out:
# array([0.30551074, 0.54934067, 0.39850992, ..., 0.81488881, 0.27831572,
#        0.97771862])

# %%
fpr,tpr,thresold=roc_curve(test_y,y_pred_prob)

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , ..., 0.91311755, 0.91311755,
#        1.        ])

# %%
tpr
# Out:
# array([0.00000000e+00, 7.48502994e-04, 8.98203593e-03, ...,
#        9.99251497e-01, 1.00000000e+00, 1.00000000e+00])

# %%
thresold
# Out:
# array([1.97771862e+00, 9.77718620e-01, 9.45483019e-01, ...,
#        1.14570989e-02, 1.14381296e-02, 1.04171349e-03])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label="Logistic Regression")
plt.xlabel("False Postive Rate")
plt.ylabel("True Postive Rate")
plt.title("Logistic Regression")
plt.show()

# %%
roc_score=roc_auc_score(test_y,y_pred_prob)
roc_score
# Out:
# 0.8518748278570627

# %% [markdown]
#  Hence the roc_auc score for Logistic Regression Model is 85.18%

# %% [markdown]
# # Crosvalidation

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_score=cross_val_score(lg,x,y,cv=2)
mean_accuracy=cv_score.mean()

# %%
mean_accuracy
# Out:
# 0.8287559277212794

# %%
cv_score=cross_val_score(lg,x,y,cv=3)
mean_accuracy=cv_score.mean()
mean_accuracy
# Out:
# 0.8281723018565122

# %%
cv_score=cross_val_score(lg,x,y,cv=4)
mean_accuracy=cv_score.mean()
mean_accuracy
# Out:
# 0.8285371541095651

# %%
cv_score=cross_val_score(lg,x,y,cv=5)
mean_accuracy=cv_score.mean()
mean_accuracy
# Out:
# 0.8285736178384671

# %% [markdown]
# from above we can find that At cv=2 we have getting the highest mean accuracy for model=82.87%

# %% [markdown]
# # Classifiers

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
for i in range(2,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.22,random_state=i)
        knn.fit(train_x,train_y)
        predknn=knn.predict(test_x)
        print(f"at random_state{i},the testing accuracy score is := {accuracy_score(test_y,predknn)}")
        print(f"at random_state{i},the training accuracy is: =      {knn.score(train_x,train_y)}")
        print(f"at random_state{i},the confusion_matrix is:=        {confusion_matrix(test_y,predknn)}")
        print(f"at random_state{i},the classification_report is:=   {classification_report(test_y,predknn)}")
        print("\n")
# Out:
# at random_state2,the testing accuracy score is := 0.8260941644562334
# at random_state2,the training accuracy is: =      0.8782791676408698
# at random_state2,the confusion_matrix is:=        [[4216  458]
#  [ 591  767]]
# at random_state2,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4674
#          1.0       0.63      0.56      0.59      1358
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state3,the testing accuracy score is := 0.8285809018567639
# at random_state3,the training accuracy is: =      0.8780453588964228
# at random_state3,the confusion_matrix is:=        [[4230  467]
#  [ 567  768]]
# at random_state3,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4697
#          1.0       0.62      0.58      0.60      1335
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state4,the testing accuracy score is := 0.8254310344827587
# at random_state4,the training accuracy is: =      0.8763151741875146
# at random_state4,the confusion_matrix is:=        [[4186  425]
#  [ 628  793]]
# at random_state4,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.91      0.89      4611
#          1.0       0.65      0.56      0.60      1421
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state5,the testing accuracy score is := 0.8322281167108754
# at random_state5,the training accuracy is: =      0.8754267009586159
# at random_state5,the confusion_matrix is:=        [[4266  441]
#  [ 571  754]]
# at random_state5,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4707
#          1.0       0.63      0.57      0.60      1325
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state6,the testing accuracy score is := 0.8277519893899205
# at random_state6,the training accuracy is: =      0.8752396539630583
# at random_state6,the confusion_matrix is:=        [[4227  450]
#  [ 589  766]]
# at random_state6,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4677
#          1.0       0.63      0.57      0.60      1355
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state7,the testing accuracy score is := 0.8244363395225465
# at random_state7,the training accuracy is: =      0.8782791676408698
# at random_state7,the confusion_matrix is:=        [[4228  473]
#  [ 586  745]]
# at random_state7,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4701
#          1.0       0.61      0.56      0.58      1331
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state8,the testing accuracy score is := 0.8267572944297082
# at random_state8,the training accuracy is: =      0.878185644143091
# at random_state8,the confusion_matrix is:=        [[4208  444]
#  [ 601  779]]
# at random_state8,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4652
#          1.0       0.64      0.56      0.60      1380
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state9,the testing accuracy score is := 0.8318965517241379
# at random_state9,the training accuracy is: =      0.8758007949497311
# at random_state9,the confusion_matrix is:=        [[4244  458]
#  [ 556  774]]
# at random_state9,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4702
#          1.0       0.63      0.58      0.60      1330
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state10,the testing accuracy score is := 0.8192970822281167
# at random_state10,the training accuracy is: =      0.8801496375964462
# at random_state10,the confusion_matrix is:=        [[4187  465]
#  [ 625  755]]
# at random_state10,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88      4652
#          1.0       0.62      0.55      0.58      1380
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.72      0.73      6032
# weighted avg       0.81      0.82      0.82      6032
#
#
#
# at random_state11,the testing accuracy score is := 0.8259283819628647
# at random_state11,the training accuracy is: =      0.8795417348608838
# at random_state11,the confusion_matrix is:=        [[4204  454]
#  [ 596  778]]
# at random_state11,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4658
#          1.0       0.63      0.57      0.60      1374
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state12,the testing accuracy score is := 0.8221153846153846
# at random_state12,the training accuracy is: =      0.8779050736497545
# at random_state12,the confusion_matrix is:=        [[4248  471]
#  [ 602  711]]
# at random_state12,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4719
#          1.0       0.60      0.54      0.57      1313
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.72      0.73      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state13,the testing accuracy score is := 0.8169761273209549
# at random_state13,the training accuracy is: =      0.8809913490764555
# at random_state13,the confusion_matrix is:=        [[4175  489]
#  [ 615  753]]
# at random_state13,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88      4664
#          1.0       0.61      0.55      0.58      1368
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.72      0.73      6032
# weighted avg       0.81      0.82      0.81      6032
#
#
#
# at random_state14,the testing accuracy score is := 0.8249336870026526
# at random_state14,the training accuracy is: =      0.8777647884030862
# at random_state14,the confusion_matrix is:=        [[4215  421]
#  [ 635  761]]
# at random_state14,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.91      0.89      4636
#          1.0       0.64      0.55      0.59      1396
#
#     accuracy                           0.82      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state15,the testing accuracy score is := 0.8249336870026526
# at random_state15,the training accuracy is: =      0.8780453588964228
# at random_state15,the confusion_matrix is:=        [[4198  448]
#  [ 608  778]]
# at random_state15,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4646
#          1.0       0.63      0.56      0.60      1386
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state16,the testing accuracy score is := 0.8236074270557029
# at random_state16,the training accuracy is: =      0.8789805938742109
# at random_state16,the confusion_matrix is:=        [[4188  432]
#  [ 632  780]]
# at random_state16,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.91      0.89      4620
#          1.0       0.64      0.55      0.59      1412
#
#     accuracy                           0.82      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state17,the testing accuracy score is := 0.8272546419098143
# at random_state17,the training accuracy is: =      0.8766892681786299
# at random_state17,the confusion_matrix is:=        [[4213  450]
#  [ 592  777]]
# at random_state17,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4663
#          1.0       0.63      0.57      0.60      1369
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state18,the testing accuracy score is := 0.8277519893899205
# at random_state18,the training accuracy is: =      0.8758475566986206
# at random_state18,the confusion_matrix is:=        [[4193  458]
#  [ 581  800]]
# at random_state18,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4651
#          1.0       0.64      0.58      0.61      1381
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state19,the testing accuracy score is := 0.8250994694960212
# at random_state19,the training accuracy is: =      0.8769698386719663
# at random_state19,the confusion_matrix is:=        [[4183  442]
#  [ 613  794]]
# at random_state19,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4625
#          1.0       0.64      0.56      0.60      1407
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state20,the testing accuracy score is := 0.8247679045092838
# at random_state20,the training accuracy is: =      0.8794014496142156
# at random_state20,the confusion_matrix is:=        [[4244  443]
#  [ 614  731]]
# at random_state20,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.91      0.89      4687
#          1.0       0.62      0.54      0.58      1345
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.72      0.73      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state21,the testing accuracy score is := 0.8212864721485411
# at random_state21,the training accuracy is: =      0.8771101239186345
# at random_state21,the confusion_matrix is:=        [[4199  467]
#  [ 611  755]]
# at random_state21,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4666
#          1.0       0.62      0.55      0.58      1366
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.73      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state22,the testing accuracy score is := 0.8315649867374005
# at random_state22,the training accuracy is: =      0.8739303249941548
# at random_state22,the confusion_matrix is:=        [[4234  461]
#  [ 555  782]]
# at random_state22,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4695
#          1.0       0.63      0.58      0.61      1337
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state23,the testing accuracy score is := 0.8300729442970822
# at random_state23,the training accuracy is: =      0.8767360299275193
# at random_state23,the confusion_matrix is:=        [[4244  449]
#  [ 576  763]]
# at random_state23,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4693
#          1.0       0.63      0.57      0.60      1339
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state24,the testing accuracy score is := 0.8260941644562334
# at random_state24,the training accuracy is: =      0.8772504091653028
# at random_state24,the confusion_matrix is:=        [[4211  462]
#  [ 587  772]]
# at random_state24,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4673
#          1.0       0.63      0.57      0.60      1359
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state25,the testing accuracy score is := 0.8292440318302388
# at random_state25,the training accuracy is: =      0.877390694411971
# at random_state25,the confusion_matrix is:=        [[4245  440]
#  [ 590  757]]
# at random_state25,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4685
#          1.0       0.63      0.56      0.60      1347
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state26,the testing accuracy score is := 0.8282493368700266
# at random_state26,the training accuracy is: =      0.8772036474164133
# at random_state26,the confusion_matrix is:=        [[4245  462]
#  [ 574  751]]
# at random_state26,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4707
#          1.0       0.62      0.57      0.59      1325
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state27,the testing accuracy score is := 0.8289124668435013
# at random_state27,the training accuracy is: =      0.8766425064297405
# at random_state27,the confusion_matrix is:=        [[4256  450]
#  [ 582  744]]
# at random_state27,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4706
#          1.0       0.62      0.56      0.59      1326
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state28,the testing accuracy score is := 0.824104774535809
# at random_state28,the training accuracy is: =      0.878419452887538
# at random_state28,the confusion_matrix is:=        [[4184  461]
#  [ 600  787]]
# at random_state28,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4645
#          1.0       0.63      0.57      0.60      1387
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state29,the testing accuracy score is := 0.8277519893899205
# at random_state29,the training accuracy is: =      0.8791208791208791
# at random_state29,the confusion_matrix is:=        [[4224  453]
#  [ 586  769]]
# at random_state29,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4677
#          1.0       0.63      0.57      0.60      1355
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state30,the testing accuracy score is := 0.819131299734748
# at random_state30,the training accuracy is: =      0.8787000233808745
# at random_state30,the confusion_matrix is:=        [[4207  488]
#  [ 603  734]]
# at random_state30,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4695
#          1.0       0.60      0.55      0.57      1337
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.72      0.73      6032
# weighted avg       0.81      0.82      0.82      6032
#
#
#
# at random_state31,the testing accuracy score is := 0.8280835543766578
# at random_state31,the training accuracy is: =      0.8772971709141922
# at random_state31,the confusion_matrix is:=        [[4235  433]
#  [ 604  760]]
# at random_state31,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4668
#          1.0       0.64      0.56      0.59      1364
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state32,the testing accuracy score is := 0.8244363395225465
# at random_state32,the training accuracy is: =      0.8795884966097732
# at random_state32,the confusion_matrix is:=        [[4228  473]
#  [ 586  745]]
# at random_state32,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4701
#          1.0       0.61      0.56      0.58      1331
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state33,the testing accuracy score is := 0.8246021220159151
# at random_state33,the training accuracy is: =      0.8789805938742109
# at random_state33,the confusion_matrix is:=        [[4228  470]
#  [ 588  746]]
# at random_state33,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4698
#          1.0       0.61      0.56      0.59      1334
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state34,the testing accuracy score is := 0.8272546419098143
# at random_state34,the training accuracy is: =      0.8789338321253215
# at random_state34,the confusion_matrix is:=        [[4215  442]
#  [ 600  775]]
# at random_state34,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4657
#          1.0       0.64      0.56      0.60      1375
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state35,the testing accuracy score is := 0.824104774535809
# at random_state35,the training accuracy is: =      0.8766892681786299
# at random_state35,the confusion_matrix is:=        [[4155  476]
#  [ 585  816]]
# at random_state35,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4631
#          1.0       0.63      0.58      0.61      1401
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.74      0.75      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state36,the testing accuracy score is := 0.8252652519893899
# at random_state36,the training accuracy is: =      0.8787467851297639
# at random_state36,the confusion_matrix is:=        [[4205  476]
#  [ 578  773]]
# at random_state36,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4681
#          1.0       0.62      0.57      0.59      1351
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state37,the testing accuracy score is := 0.8325596816976127
# at random_state37,the training accuracy is: =      0.8775309796586392
# at random_state37,the confusion_matrix is:=        [[4271  477]
#  [ 533  751]]
# at random_state37,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.89      4748
#          1.0       0.61      0.58      0.60      1284
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state38,the testing accuracy score is := 0.8184681697612732
# at random_state38,the training accuracy is: =      0.8787000233808745
# at random_state38,the confusion_matrix is:=        [[4161  487]
#  [ 608  776]]
# at random_state38,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88      4648
#          1.0       0.61      0.56      0.59      1384
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.73      0.74      6032
# weighted avg       0.81      0.82      0.82      6032
#
#
#
# at random_state39,the testing accuracy score is := 0.8358753315649867
# at random_state39,the training accuracy is: =      0.876128127191957
# at random_state39,the confusion_matrix is:=        [[4295  433]
#  [ 557  747]]
# at random_state39,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.91      0.90      4728
#          1.0       0.63      0.57      0.60      1304
#
#     accuracy                           0.84      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.84      0.83      6032
#
#
#
# at random_state40,the testing accuracy score is := 0.8277519893899205
# at random_state40,the training accuracy is: =      0.8774374561608604
# at random_state40,the confusion_matrix is:=        [[4221  464]
#  [ 575  772]]
# at random_state40,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4685
#          1.0       0.62      0.57      0.60      1347
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state41,the testing accuracy score is := 0.82907824933687
# at random_state41,the training accuracy is: =      0.8782791676408698
# at random_state41,the confusion_matrix is:=        [[4253  427]
#  [ 604  748]]
# at random_state41,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4680
#          1.0       0.64      0.55      0.59      1352
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state42,the testing accuracy score is := 0.8246021220159151
# at random_state42,the training accuracy is: =      0.8784662146364274
# at random_state42,the confusion_matrix is:=        [[4213  464]
#  [ 594  761]]
# at random_state42,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4677
#          1.0       0.62      0.56      0.59      1355
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state43,the testing accuracy score is := 0.827420424403183
# at random_state43,the training accuracy is: =      0.878185644143091
# at random_state43,the confusion_matrix is:=        [[4218  472]
#  [ 569  773]]
# at random_state43,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4690
#          1.0       0.62      0.58      0.60      1342
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state44,the testing accuracy score is := 0.8277519893899205
# at random_state44,the training accuracy is: =      0.8782791676408698
# at random_state44,the confusion_matrix is:=        [[4210  440]
#  [ 599  783]]
# at random_state44,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4650
#          1.0       0.64      0.57      0.60      1382
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state45,the testing accuracy score is := 0.8221153846153846
# at random_state45,the training accuracy is: =      0.8783726911386486
# at random_state45,the confusion_matrix is:=        [[4197  441]
#  [ 632  762]]
# at random_state45,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4638
#          1.0       0.63      0.55      0.59      1394
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.81      0.82      0.82      6032
#
#
#
# at random_state46,the testing accuracy score is := 0.8372015915119363
# at random_state46,the training accuracy is: =      0.8754734627075053
# at random_state46,the confusion_matrix is:=        [[4264  437]
#  [ 545  786]]
# at random_state46,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.91      0.90      4701
#          1.0       0.64      0.59      0.62      1331
#
#     accuracy                           0.84      6032
#    macro avg       0.76      0.75      0.76      6032
# weighted avg       0.83      0.84      0.83      6032
#
#
#
# at random_state47,the testing accuracy score is := 0.8262599469496021
# at random_state47,the training accuracy is: =      0.8791676408697685
# at random_state47,the confusion_matrix is:=        [[4204  447]
#  [ 601  780]]
# at random_state47,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4651
#          1.0       0.64      0.56      0.60      1381
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state48,the testing accuracy score is := 0.8297413793103449
# at random_state48,the training accuracy is: =      0.87509936871639
# at random_state48,the confusion_matrix is:=        [[4244  481]
#  [ 546  761]]
# at random_state48,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.89      4725
#          1.0       0.61      0.58      0.60      1307
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state49,the testing accuracy score is := 0.8307360742705571
# at random_state49,the training accuracy is: =      0.876128127191957
# at random_state49,the confusion_matrix is:=        [[4212  464]
#  [ 557  799]]
# at random_state49,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4676
#          1.0       0.63      0.59      0.61      1356
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.75      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state50,the testing accuracy score is := 0.8279177718832891
# at random_state50,the training accuracy is: =      0.876361935936404
# at random_state50,the confusion_matrix is:=        [[4260  409]
#  [ 629  734]]
# at random_state50,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.91      0.89      4669
#          1.0       0.64      0.54      0.59      1363
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state51,the testing accuracy score is := 0.8209549071618037
# at random_state51,the training accuracy is: =      0.8787935468786533
# at random_state51,the confusion_matrix is:=        [[4208  482]
#  [ 598  744]]
# at random_state51,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4690
#          1.0       0.61      0.55      0.58      1342
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.73      0.73      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state52,the testing accuracy score is := 0.8317307692307693
# at random_state52,the training accuracy is: =      0.8769230769230769
# at random_state52,the confusion_matrix is:=        [[4256  447]
#  [ 568  761]]
# at random_state52,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4703
#          1.0       0.63      0.57      0.60      1329
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state53,the testing accuracy score is := 0.8327254641909815
# at random_state53,the training accuracy is: =      0.8779050736497545
# at random_state53,the confusion_matrix is:=        [[4262  435]
#  [ 574  761]]
# at random_state53,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4697
#          1.0       0.64      0.57      0.60      1335
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state54,the testing accuracy score is := 0.8164787798408488
# at random_state54,the training accuracy is: =      0.8789338321253215
# at random_state54,the confusion_matrix is:=        [[4181  493]
#  [ 614  744]]
# at random_state54,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.89      0.88      4674
#          1.0       0.60      0.55      0.57      1358
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.72      0.73      6032
# weighted avg       0.81      0.82      0.81      6032
#
#
#
# at random_state55,the testing accuracy score is := 0.8262599469496021
# at random_state55,the training accuracy is: =      0.8760346036941782
# at random_state55,the confusion_matrix is:=        [[4221  451]
#  [ 597  763]]
# at random_state55,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4672
#          1.0       0.63      0.56      0.59      1360
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state56,the testing accuracy score is := 0.8305702917771883
# at random_state56,the training accuracy is: =      0.8758007949497311
# at random_state56,the confusion_matrix is:=        [[4253  471]
#  [ 551  757]]
# at random_state56,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.89      4724
#          1.0       0.62      0.58      0.60      1308
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state57,the testing accuracy score is := 0.8289124668435013
# at random_state57,the training accuracy is: =      0.8765022211830722
# at random_state57,the confusion_matrix is:=        [[4206  447]
#  [ 585  794]]
# at random_state57,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4653
#          1.0       0.64      0.58      0.61      1379
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state58,the testing accuracy score is := 0.8144893899204244
# at random_state58,the training accuracy is: =      0.879915828851999
# at random_state58,the confusion_matrix is:=        [[4184  476]
#  [ 643  729]]
# at random_state58,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88      4660
#          1.0       0.60      0.53      0.57      1372
#
#     accuracy                           0.81      6032
#    macro avg       0.74      0.71      0.72      6032
# weighted avg       0.81      0.81      0.81      6032
#
#
#
# at random_state59,the testing accuracy score is := 0.8166445623342176
# at random_state59,the training accuracy is: =      0.8803834463408932
# at random_state59,the confusion_matrix is:=        [[4139  477]
#  [ 629  787]]
# at random_state59,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88      4616
#          1.0       0.62      0.56      0.59      1416
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.73      6032
# weighted avg       0.81      0.82      0.81      6032
#
#
#
# at random_state60,the testing accuracy score is := 0.8239389920424404
# at random_state60,the training accuracy is: =      0.8790273556231003
# at random_state60,the confusion_matrix is:=        [[4194  493]
#  [ 569  776]]
# at random_state60,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.89      0.89      4687
#          1.0       0.61      0.58      0.59      1345
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state61,the testing accuracy score is := 0.8242705570291777
# at random_state61,the training accuracy is: =      0.877390694411971
# at random_state61,the confusion_matrix is:=        [[4211  483]
#  [ 577  761]]
# at random_state61,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4694
#          1.0       0.61      0.57      0.59      1338
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state62,the testing accuracy score is := 0.8259283819628647
# at random_state62,the training accuracy is: =      0.8798690671031096
# at random_state62,the confusion_matrix is:=        [[4235  476]
#  [ 574  747]]
# at random_state62,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4711
#          1.0       0.61      0.57      0.59      1321
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state63,the testing accuracy score is := 0.8313992042440318
# at random_state63,the training accuracy is: =      0.8764086976852934
# at random_state63,the confusion_matrix is:=        [[4269  490]
#  [ 527  746]]
# at random_state63,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.89      4759
#          1.0       0.60      0.59      0.59      1273
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state64,the testing accuracy score is := 0.8166445623342176
# at random_state64,the training accuracy is: =      0.8780453588964228
# at random_state64,the confusion_matrix is:=        [[4183  455]
#  [ 651  743]]
# at random_state64,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88      4638
#          1.0       0.62      0.53      0.57      1394
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.72      0.73      6032
# weighted avg       0.81      0.82      0.81      6032
#
#
#
# at random_state65,the testing accuracy score is := 0.8312334217506632
# at random_state65,the training accuracy is: =      0.8780453588964228
# at random_state65,the confusion_matrix is:=        [[4239  444]
#  [ 574  775]]
# at random_state65,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4683
#          1.0       0.64      0.57      0.60      1349
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state66,the testing accuracy score is := 0.8275862068965517
# at random_state66,the training accuracy is: =      0.8777180266541968
# at random_state66,the confusion_matrix is:=        [[4221  464]
#  [ 576  771]]
# at random_state66,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4685
#          1.0       0.62      0.57      0.60      1347
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state67,the testing accuracy score is := 0.8343832891246684
# at random_state67,the training accuracy is: =      0.8777647884030862
# at random_state67,the confusion_matrix is:=        [[4252  400]
#  [ 599  781]]
# at random_state67,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4652
#          1.0       0.66      0.57      0.61      1380
#
#     accuracy                           0.83      6032
#    macro avg       0.77      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state68,the testing accuracy score is := 0.8229442970822282
# at random_state68,the training accuracy is: =      0.8790741173719897
# at random_state68,the confusion_matrix is:=        [[4242  461]
#  [ 607  722]]
# at random_state68,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4703
#          1.0       0.61      0.54      0.57      1329
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.72      0.73      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state69,the testing accuracy score is := 0.8168103448275862
# at random_state69,the training accuracy is: =      0.8798223053542202
# at random_state69,the confusion_matrix is:=        [[4181  492]
#  [ 613  746]]
# at random_state69,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.89      0.88      4673
#          1.0       0.60      0.55      0.57      1359
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.72      0.73      6032
# weighted avg       0.81      0.82      0.81      6032
#
#
#
# at random_state70,the testing accuracy score is := 0.8262599469496021
# at random_state70,the training accuracy is: =      0.8779518353986439
# at random_state70,the confusion_matrix is:=        [[4222  453]
#  [ 595  762]]
# at random_state70,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4675
#          1.0       0.63      0.56      0.59      1357
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state71,the testing accuracy score is := 0.8184681697612732
# at random_state71,the training accuracy is: =      0.8785597381342062
# at random_state71,the confusion_matrix is:=        [[4230  526]
#  [ 569  707]]
# at random_state71,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.89      0.89      4756
#          1.0       0.57      0.55      0.56      1276
#
#     accuracy                           0.82      6032
#    macro avg       0.73      0.72      0.72      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state72,the testing accuracy score is := 0.8254310344827587
# at random_state72,the training accuracy is: =      0.8779518353986439
# at random_state72,the confusion_matrix is:=        [[4237  460]
#  [ 593  742]]
# at random_state72,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4697
#          1.0       0.62      0.56      0.58      1335
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state73,the testing accuracy score is := 0.8322281167108754
# at random_state73,the training accuracy is: =      0.8756137479541735
# at random_state73,the confusion_matrix is:=        [[4250  435]
#  [ 577  770]]
# at random_state73,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4685
#          1.0       0.64      0.57      0.60      1347
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state74,the testing accuracy score is := 0.8305702917771883
# at random_state74,the training accuracy is: =      0.8783726911386486
# at random_state74,the confusion_matrix is:=        [[4263  470]
#  [ 552  747]]
# at random_state74,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.89      4733
#          1.0       0.61      0.58      0.59      1299
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state75,the testing accuracy score is := 0.8280835543766578
# at random_state75,the training accuracy is: =      0.8789805938742109
# at random_state75,the confusion_matrix is:=        [[4205  479]
#  [ 558  790]]
# at random_state75,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4684
#          1.0       0.62      0.59      0.60      1348
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.75      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state76,the testing accuracy score is := 0.8294098143236074
# at random_state76,the training accuracy is: =      0.8779050736497545
# at random_state76,the confusion_matrix is:=        [[4193  440]
#  [ 589  810]]
# at random_state76,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4633
#          1.0       0.65      0.58      0.61      1399
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state77,the testing accuracy score is := 0.8315649867374005
# at random_state77,the training accuracy is: =      0.8771101239186345
# at random_state77,the confusion_matrix is:=        [[4265  464]
#  [ 552  751]]
# at random_state77,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.89      4729
#          1.0       0.62      0.58      0.60      1303
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state78,the testing accuracy score is := 0.8350464190981433
# at random_state78,the training accuracy is: =      0.8774374561608604
# at random_state78,the confusion_matrix is:=        [[4264  450]
#  [ 545  773]]
# at random_state78,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.90      4714
#          1.0       0.63      0.59      0.61      1318
#
#     accuracy                           0.84      6032
#    macro avg       0.76      0.75      0.75      6032
# weighted avg       0.83      0.84      0.83      6032
#
#
#
# at random_state79,the testing accuracy score is := 0.8315649867374005
# at random_state79,the training accuracy is: =      0.8756605097030629
# at random_state79,the confusion_matrix is:=        [[4233  443]
#  [ 573  783]]
# at random_state79,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4676
#          1.0       0.64      0.58      0.61      1356
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state80,the testing accuracy score is := 0.8294098143236074
# at random_state80,the training accuracy is: =      0.8764554594341828
# at random_state80,the confusion_matrix is:=        [[4248  463]
#  [ 566  755]]
# at random_state80,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4711
#          1.0       0.62      0.57      0.59      1321
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state81,the testing accuracy score is := 0.8322281167108754
# at random_state81,the training accuracy is: =      0.8766892681786299
# at random_state81,the confusion_matrix is:=        [[4225  481]
#  [ 531  795]]
# at random_state81,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.89      4706
#          1.0       0.62      0.60      0.61      1326
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.75      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state82,the testing accuracy score is := 0.8275862068965517
# at random_state82,the training accuracy is: =      0.876361935936404
# at random_state82,the confusion_matrix is:=        [[4230  434]
#  [ 606  762]]
# at random_state82,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.91      0.89      4664
#          1.0       0.64      0.56      0.59      1368
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state83,the testing accuracy score is := 0.8216180371352785
# at random_state83,the training accuracy is: =      0.8794014496142156
# at random_state83,the confusion_matrix is:=        [[4171  467]
#  [ 609  785]]
# at random_state83,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4638
#          1.0       0.63      0.56      0.59      1394
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state84,the testing accuracy score is := 0.8252652519893899
# at random_state84,the training accuracy is: =      0.877858311900865
# at random_state84,the confusion_matrix is:=        [[4201  445]
#  [ 609  777]]
# at random_state84,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4646
#          1.0       0.64      0.56      0.60      1386
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state85,the testing accuracy score is := 0.8343832891246684
# at random_state85,the training accuracy is: =      0.8760813654430676
# at random_state85,the confusion_matrix is:=        [[4276  438]
#  [ 561  757]]
# at random_state85,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.90      4714
#          1.0       0.63      0.57      0.60      1318
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032
#
#
#
# at random_state86,the testing accuracy score is := 0.8194628647214854
# at random_state86,the training accuracy is: =      0.8760346036941782
# at random_state86,the confusion_matrix is:=        [[4215  473]
#  [ 616  728]]
# at random_state86,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4688
#          1.0       0.61      0.54      0.57      1344
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.72      0.73      6032
# weighted avg       0.81      0.82      0.82      6032
#
#
#
# at random_state87,the testing accuracy score is := 0.8186339522546419
# at random_state87,the training accuracy is: =      0.8808978255786767
# at random_state87,the confusion_matrix is:=        [[4181  457]
#  [ 637  757]]
# at random_state87,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88      4638
#          1.0       0.62      0.54      0.58      1394
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.72      0.73      6032
# weighted avg       0.81      0.82      0.81      6032
#
#
#
# at random_state88,the testing accuracy score is := 0.8250994694960212
# at random_state88,the training accuracy is: =      0.8783259293897592
# at random_state88,the confusion_matrix is:=        [[4191  483]
#  [ 572  786]]
# at random_state88,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4674
#          1.0       0.62      0.58      0.60      1358
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state89,the testing accuracy score is := 0.8254310344827587
# at random_state89,the training accuracy is: =      0.8763151741875146
# at random_state89,the confusion_matrix is:=        [[4220  480]
#  [ 573  759]]
# at random_state89,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4700
#          1.0       0.61      0.57      0.59      1332
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state90,the testing accuracy score is := 0.8262599469496021
# at random_state90,the training accuracy is: =      0.8792611643675473
# at random_state90,the confusion_matrix is:=        [[4226  485]
#  [ 563  758]]
# at random_state90,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4711
#          1.0       0.61      0.57      0.59      1321
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state91,the testing accuracy score is := 0.8229442970822282
# at random_state91,the training accuracy is: =      0.8781388823942016
# at random_state91,the confusion_matrix is:=        [[4215  443]
#  [ 625  749]]
# at random_state91,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4658
#          1.0       0.63      0.55      0.58      1374
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state92,the testing accuracy score is := 0.8196286472148541
# at random_state92,the training accuracy is: =      0.8787000233808745
# at random_state92,the confusion_matrix is:=        [[4166  456]
#  [ 632  778]]
# at random_state92,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88      4622
#          1.0       0.63      0.55      0.59      1410
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.81      0.82      0.82      6032
#
#
#
# at random_state93,the testing accuracy score is := 0.8222811671087533
# at random_state93,the training accuracy is: =      0.877624503156418
# at random_state93,the confusion_matrix is:=        [[4191  447]
#  [ 625  769]]
# at random_state93,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4638
#          1.0       0.63      0.55      0.59      1394
#
#     accuracy                           0.82      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state94,the testing accuracy score is := 0.8252652519893899
# at random_state94,the training accuracy is: =      0.8780921206453122
# at random_state94,the confusion_matrix is:=        [[4237  466]
#  [ 588  741]]
# at random_state94,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4703
#          1.0       0.61      0.56      0.58      1329
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state95,the testing accuracy score is := 0.8254310344827587
# at random_state95,the training accuracy is: =      0.8772036474164133
# at random_state95,the confusion_matrix is:=        [[4210  445]
#  [ 608  769]]
# at random_state95,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89      4655
#          1.0       0.63      0.56      0.59      1377
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.73      0.74      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state96,the testing accuracy score is := 0.8294098143236074
# at random_state96,the training accuracy is: =      0.8768295534252981
# at random_state96,the confusion_matrix is:=        [[4239  450]
#  [ 579  764]]
# at random_state96,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4689
#          1.0       0.63      0.57      0.60      1343
#
#     accuracy                           0.83      6032
#    macro avg       0.75      0.74      0.74      6032
# weighted avg       0.82      0.83      0.83      6032
#
#
#
# at random_state97,the testing accuracy score is := 0.8247679045092838
# at random_state97,the training accuracy is: =      0.8767827916764087
# at random_state97,the confusion_matrix is:=        [[4251  459]
#  [ 598  724]]
# at random_state97,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4710
#          1.0       0.61      0.55      0.58      1322
#
#     accuracy                           0.82      6032
#    macro avg       0.74      0.73      0.73      6032
# weighted avg       0.82      0.82      0.82      6032
#
#
#
# at random_state98,the testing accuracy score is := 0.8270888594164456
# at random_state98,the training accuracy is: =      0.8780921206453122
# at random_state98,the confusion_matrix is:=        [[4194  452]
#  [ 591  795]]
# at random_state98,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89      4646
#          1.0       0.64      0.57      0.60      1386
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.82      0.83      0.82      6032
#
#
#
# at random_state99,the testing accuracy score is := 0.8327254641909815
# at random_state99,the training accuracy is: =      0.87509936871639
# at random_state99,the confusion_matrix is:=        [[4269  427]
#  [ 582  754]]
# at random_state99,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89      4696
#          1.0       0.64      0.56      0.60      1336
#
#     accuracy                           0.83      6032
#    macro avg       0.76      0.74      0.75      6032
# weighted avg       0.83      0.83      0.83      6032

# %% [markdown]
#  at random_state46,thebest testing accuracy score for KNN model is := 0.8372015915119363
# at random_state46,the training accuracyfor KNN model is: =      0.8754734627075053

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()

# %%
for i in range(2,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.22,random_state=i)
        gnb.fit(train_x,train_y)
        predgnb=gnb.predict(test_x)
        print(f"at random_state{i},the testing accuracy score is := {accuracy_score(test_y,predgnb)}")
        print(f"at random_state{i},the training accuracy is: =      {knn.score(train_x,train_y)}")
        print(f"at random_state{i},the confusion_matrix is:=        {confusion_matrix(test_y,predgnb)}")
        print(f"at random_state{i},the classification_report is:=   {classification_report(test_y,predgnb)}")
        print("\n")
# Out:
# at random_state2,the testing accuracy score is := 0.7670755968169761
# at random_state2,the training accuracy is: =      0.8643909282207155
# at random_state2,the confusion_matrix is:=        [[3586 1088]
#  [ 317 1041]]
# at random_state2,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4674
#          1.0       0.49      0.77      0.60      1358
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state3,the testing accuracy score is := 0.7652519893899205
# at random_state3,the training accuracy is: =      0.8660275894318448
# at random_state3,the confusion_matrix is:=        [[3578 1119]
#  [ 297 1038]]
# at random_state3,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4697
#          1.0       0.48      0.78      0.59      1335
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.77      0.78      6032
#
#
#
# at random_state4,the testing accuracy score is := 0.7596153846153846
# at random_state4,the training accuracy is: =      0.8655132101940612
# at random_state4,the confusion_matrix is:=        [[3436 1175]
#  [ 275 1146]]
# at random_state4,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4611
#          1.0       0.49      0.81      0.61      1421
#
#     accuracy                           0.76      6032
#    macro avg       0.71      0.78      0.72      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state5,the testing accuracy score is := 0.7607758620689655
# at random_state5,the training accuracy is: =      0.8656534954407294
# at random_state5,the confusion_matrix is:=        [[3592 1115]
#  [ 328  997]]
# at random_state5,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4707
#          1.0       0.47      0.75      0.58      1325
#
#     accuracy                           0.76      6032
#    macro avg       0.69      0.76      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state6,the testing accuracy score is := 0.7584549071618037
# at random_state6,the training accuracy is: =      0.8640635959784896
# at random_state6,the confusion_matrix is:=        [[3504 1173]
#  [ 284 1071]]
# at random_state6,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4677
#          1.0       0.48      0.79      0.60      1355
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state7,the testing accuracy score is := 0.7556366047745358
# at random_state7,the training accuracy is: =      0.8658873041851766
# at random_state7,the confusion_matrix is:=        [[3494 1207]
#  [ 267 1064]]
# at random_state7,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.74      0.83      4701
#          1.0       0.47      0.80      0.59      1331
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.77      6032
#
#
#
# at random_state8,the testing accuracy score is := 0.7581233421750663
# at random_state8,the training accuracy is: =      0.8650455927051671
# at random_state8,the confusion_matrix is:=        [[3492 1160]
#  [ 299 1081]]
# at random_state8,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4652
#          1.0       0.48      0.78      0.60      1380
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.76      0.77      6032
#
#
#
# at random_state9,the testing accuracy score is := 0.7712201591511937
# at random_state9,the training accuracy is: =      0.8651858779518354
# at random_state9,the confusion_matrix is:=        [[3632 1070]
#  [ 310 1020]]
# at random_state9,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4702
#          1.0       0.49      0.77      0.60      1330
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.72      6032
# weighted avg       0.83      0.77      0.79      6032
#
#
#
# at random_state10,the testing accuracy score is := 0.7630968169761273
# at random_state10,the training accuracy is: =      0.8679915828852
# at random_state10,the confusion_matrix is:=        [[3512 1140]
#  [ 289 1091]]
# at random_state10,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4652
#          1.0       0.49      0.79      0.60      1380
#
#     accuracy                           0.76      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state11,the testing accuracy score is := 0.7604442970822282
# at random_state11,the training accuracy is: =      0.8652794014496142
# at random_state11,the confusion_matrix is:=        [[3504 1154]
#  [ 291 1083]]
# at random_state11,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4658
#          1.0       0.48      0.79      0.60      1374
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state12,the testing accuracy score is := 0.7621021220159151
# at random_state12,the training accuracy is: =      0.8664952069207388
# at random_state12,the confusion_matrix is:=        [[3581 1138]
#  [ 297 1016]]
# at random_state12,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4719
#          1.0       0.47      0.77      0.59      1313
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state13,the testing accuracy score is := 0.7670755968169761
# at random_state13,the training accuracy is: =      0.8674772036474164
# at random_state13,the confusion_matrix is:=        [[3559 1105]
#  [ 300 1068]]
# at random_state13,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.84      4664
#          1.0       0.49      0.78      0.60      1368
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state14,the testing accuracy score is := 0.7645888594164456
# at random_state14,the training accuracy is: =      0.8653261631985036
# at random_state14,the confusion_matrix is:=        [[3530 1106]
#  [ 314 1082]]
# at random_state14,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4636
#          1.0       0.49      0.78      0.60      1396
#
#     accuracy                           0.76      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state15,the testing accuracy score is := 0.35958222811671087
# at random_state15,the training accuracy is: =      0.8652794014496142
# at random_state15,the confusion_matrix is:=        [[ 800 3846]
#  [  17 1369]]
# at random_state15,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.98      0.17      0.29      4646
#          1.0       0.26      0.99      0.41      1386
#
#     accuracy                           0.36      6032
#    macro avg       0.62      0.58      0.35      6032
# weighted avg       0.81      0.36      0.32      6032
#
#
#
# at random_state16,the testing accuracy score is := 0.7556366047745358
# at random_state16,the training accuracy is: =      0.8673369184007482
# at random_state16,the confusion_matrix is:=        [[3457 1163]
#  [ 311 1101]]
# at random_state16,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.82      4620
#          1.0       0.49      0.78      0.60      1412
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.76      0.77      6032
#
#
#
# at random_state17,the testing accuracy score is := 0.7625994694960212
# at random_state17,the training accuracy is: =      0.8662613981762918
# at random_state17,the confusion_matrix is:=        [[3549 1114]
#  [ 318 1051]]
# at random_state17,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4663
#          1.0       0.49      0.77      0.59      1369
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state18,the testing accuracy score is := 0.7589522546419099
# at random_state18,the training accuracy is: =      0.8650455927051671
# at random_state18,the confusion_matrix is:=        [[3495 1156]
#  [ 298 1083]]
# at random_state18,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4651
#          1.0       0.48      0.78      0.60      1381
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state19,the testing accuracy score is := 0.7659151193633952
# at random_state19,the training accuracy is: =      0.8656534954407294
# at random_state19,the confusion_matrix is:=        [[3522 1103]
#  [ 309 1098]]
# at random_state19,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4625
#          1.0       0.50      0.78      0.61      1407
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state20,the testing accuracy score is := 0.7659151193633952
# at random_state20,the training accuracy is: =      0.8665887304185177
# at random_state20,the confusion_matrix is:=        [[3564 1123]
#  [ 289 1056]]
# at random_state20,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4687
#          1.0       0.48      0.79      0.60      1345
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.72      6032
# weighted avg       0.83      0.77      0.78      6032
#
#
#
# at random_state21,the testing accuracy score is := 0.7667440318302388
# at random_state21,the training accuracy is: =      0.8671966331540799
# at random_state21,the confusion_matrix is:=        [[3583 1083]
#  [ 324 1042]]
# at random_state21,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4666
#          1.0       0.49      0.76      0.60      1366
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state22,the testing accuracy score is := 0.7695623342175066
# at random_state22,the training accuracy is: =      0.8654196866962824
# at random_state22,the confusion_matrix is:=        [[3607 1088]
#  [ 302 1035]]
# at random_state22,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4695
#          1.0       0.49      0.77      0.60      1337
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.83      0.77      0.79      6032
#
#
#
# at random_state23,the testing accuracy score is := 0.7644230769230769
# at random_state23,the training accuracy is: =      0.8643909282207155
# at random_state23,the confusion_matrix is:=        [[3535 1158]
#  [ 263 1076]]
# at random_state23,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4693
#          1.0       0.48      0.80      0.60      1339
#
#     accuracy                           0.76      6032
#    macro avg       0.71      0.78      0.72      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state24,the testing accuracy score is := 0.7607758620689655
# at random_state24,the training accuracy is: =      0.8653261631985036
# at random_state24,the confusion_matrix is:=        [[3510 1163]
#  [ 280 1079]]
# at random_state24,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4673
#          1.0       0.48      0.79      0.60      1359
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state25,the testing accuracy score is := 0.7766909814323607
# at random_state25,the training accuracy is: =      0.8659808276829554
# at random_state25,the confusion_matrix is:=        [[3631 1054]
#  [ 293 1054]]
# at random_state25,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.78      0.84      4685
#          1.0       0.50      0.78      0.61      1347
#
#     accuracy                           0.78      6032
#    macro avg       0.71      0.78      0.73      6032
# weighted avg       0.83      0.78      0.79      6032
#
#
#
# at random_state26,the testing accuracy score is := 0.7650862068965517
# at random_state26,the training accuracy is: =      0.8660275894318448
# at random_state26,the confusion_matrix is:=        [[3586 1121]
#  [ 296 1029]]
# at random_state26,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.84      4707
#          1.0       0.48      0.78      0.59      1325
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.77      0.78      6032
#
#
#
# at random_state27,the testing accuracy score is := 0.7821618037135278
# at random_state27,the training accuracy is: =      0.8648585457096095
# at random_state27,the confusion_matrix is:=        [[3682 1024]
#  [ 290 1036]]
# at random_state27,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.78      0.85      4706
#          1.0       0.50      0.78      0.61      1326
#
#     accuracy                           0.78      6032
#    macro avg       0.71      0.78      0.73      6032
# weighted avg       0.83      0.78      0.80      6032
#
#
#
# at random_state28,the testing accuracy score is := 0.7695623342175066
# at random_state28,the training accuracy is: =      0.8671966331540799
# at random_state28,the confusion_matrix is:=        [[3571 1074]
#  [ 316 1071]]
# at random_state28,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4645
#          1.0       0.50      0.77      0.61      1387
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state29,the testing accuracy score is := 0.7589522546419099
# at random_state29,the training accuracy is: =      0.8656534954407294
# at random_state29,the confusion_matrix is:=        [[3507 1170]
#  [ 284 1071]]
# at random_state29,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4677
#          1.0       0.48      0.79      0.60      1355
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state30,the testing accuracy score is := 0.7589522546419099
# at random_state30,the training accuracy is: =      0.8688332943652093
# at random_state30,the confusion_matrix is:=        [[3511 1184]
#  [ 270 1067]]
# at random_state30,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4695
#          1.0       0.47      0.80      0.59      1337
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state31,the testing accuracy score is := 0.7740384615384616
# at random_state31,the training accuracy is: =      0.8643909282207155
# at random_state31,the confusion_matrix is:=        [[3614 1054]
#  [ 309 1055]]
# at random_state31,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4668
#          1.0       0.50      0.77      0.61      1364
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.83      0.77      0.79      6032
#
#
#
# at random_state32,the testing accuracy score is := 0.7639257294429708
# at random_state32,the training accuracy is: =      0.86640168342296
# at random_state32,the confusion_matrix is:=        [[3564 1137]
#  [ 287 1044]]
# at random_state32,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.76      0.83      4701
#          1.0       0.48      0.78      0.59      1331
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state33,the testing accuracy score is := 0.7659151193633952
# at random_state33,the training accuracy is: =      0.8671966331540799
# at random_state33,the confusion_matrix is:=        [[3612 1086]
#  [ 326 1008]]
# at random_state33,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4698
#          1.0       0.48      0.76      0.59      1334
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state34,the testing accuracy score is := 0.7684018567639257
# at random_state34,the training accuracy is: =      0.8657002571896188
# at random_state34,the confusion_matrix is:=        [[3584 1073]
#  [ 324 1051]]
# at random_state34,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4657
#          1.0       0.49      0.76      0.60      1375
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state35,the testing accuracy score is := 0.7642572944297082
# at random_state35,the training accuracy is: =      0.8660743511807342
# at random_state35,the confusion_matrix is:=        [[3508 1123]
#  [ 299 1102]]
# at random_state35,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4631
#          1.0       0.50      0.79      0.61      1401
#
#     accuracy                           0.76      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state36,the testing accuracy score is := 0.7577917771883289
# at random_state36,the training accuracy is: =      0.8656534954407294
# at random_state36,the confusion_matrix is:=        [[3508 1173]
#  [ 288 1063]]
# at random_state36,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4681
#          1.0       0.48      0.79      0.59      1351
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state37,the testing accuracy score is := 0.7581233421750663
# at random_state37,the training accuracy is: =      0.8633621697451485
# at random_state37,the confusion_matrix is:=        [[3541 1207]
#  [ 252 1032]]
# at random_state37,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4748
#          1.0       0.46      0.80      0.59      1284
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state38,the testing accuracy score is := 0.75
# at random_state38,the training accuracy is: =      0.8669628244096329
# at random_state38,the confusion_matrix is:=        [[3437 1211]
#  [ 297 1087]]
# at random_state38,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.74      0.82      4648
#          1.0       0.47      0.79      0.59      1384
#
#     accuracy                           0.75      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state39,the testing accuracy score is := 0.7562997347480106
# at random_state39,the training accuracy is: =      0.8639233107318214
# at random_state39,the confusion_matrix is:=        [[3540 1188]
#  [ 282 1022]]
# at random_state39,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4728
#          1.0       0.46      0.78      0.58      1304
#
#     accuracy                           0.76      6032
#    macro avg       0.69      0.77      0.70      6032
# weighted avg       0.83      0.76      0.77      6032
#
#
#
# at random_state40,the testing accuracy score is := 0.7611074270557029
# at random_state40,the training accuracy is: =      0.8655132101940612
# at random_state40,the confusion_matrix is:=        [[3587 1098]
#  [ 343 1004]]
# at random_state40,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.91      0.77      0.83      4685
#          1.0       0.48      0.75      0.58      1347
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state41,the testing accuracy score is := 0.7630968169761273
# at random_state41,the training accuracy is: =      0.8652326397007248
# at random_state41,the confusion_matrix is:=        [[3569 1111]
#  [ 318 1034]]
# at random_state41,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4680
#          1.0       0.48      0.76      0.59      1352
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state42,the testing accuracy score is := 0.7523209549071618
# at random_state42,the training accuracy is: =      0.8652794014496142
# at random_state42,the confusion_matrix is:=        [[3462 1215]
#  [ 279 1076]]
# at random_state42,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.74      0.82      4677
#          1.0       0.47      0.79      0.59      1355
#
#     accuracy                           0.75      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state43,the testing accuracy score is := 0.7541445623342176
# at random_state43,the training accuracy is: =      0.8663549216740706
# at random_state43,the confusion_matrix is:=        [[3517 1173]
#  [ 310 1032]]
# at random_state43,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4690
#          1.0       0.47      0.77      0.58      1342
#
#     accuracy                           0.75      6032
#    macro avg       0.69      0.76      0.70      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state44,the testing accuracy score is := 0.7587864721485411
# at random_state44,the training accuracy is: =      0.8655599719429506
# at random_state44,the confusion_matrix is:=        [[3468 1182]
#  [ 273 1109]]
# at random_state44,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4650
#          1.0       0.48      0.80      0.60      1382
#
#     accuracy                           0.76      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state45,the testing accuracy score is := 0.366710875331565
# at random_state45,the training accuracy is: =      0.8663081599251812
# at random_state45,the confusion_matrix is:=        [[ 831 3807]
#  [  13 1381]]
# at random_state45,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.98      0.18      0.30      4638
#          1.0       0.27      0.99      0.42      1394
#
#     accuracy                           0.37      6032
#    macro avg       0.63      0.58      0.36      6032
# weighted avg       0.82      0.37      0.33      6032
#
#
#
# at random_state46,the testing accuracy score is := 0.7629310344827587
# at random_state46,the training accuracy is: =      0.863081599251812
# at random_state46,the confusion_matrix is:=        [[3531 1170]
#  [ 260 1071]]
# at random_state46,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4701
#          1.0       0.48      0.80      0.60      1331
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.78      0.72      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state47,the testing accuracy score is := 0.36853448275862066
# at random_state47,the training accuracy is: =      0.8662613981762918
# at random_state47,the confusion_matrix is:=        [[ 860 3791]
#  [  18 1363]]
# at random_state47,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.98      0.18      0.31      4651
#          1.0       0.26      0.99      0.42      1381
#
#     accuracy                           0.37      6032
#    macro avg       0.62      0.59      0.36      6032
# weighted avg       0.82      0.37      0.34      6032
#
#
#
# at random_state48,the testing accuracy score is := 0.7604442970822282
# at random_state48,the training accuracy is: =      0.866167874678513
# at random_state48,the confusion_matrix is:=        [[3562 1163]
#  [ 282 1025]]
# at random_state48,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4725
#          1.0       0.47      0.78      0.59      1307
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state49,the testing accuracy score is := 0.7531498673740054
# at random_state49,the training accuracy is: =      0.8648117839607201
# at random_state49,the confusion_matrix is:=        [[3464 1212]
#  [ 277 1079]]
# at random_state49,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.74      0.82      4676
#          1.0       0.47      0.80      0.59      1356
#
#     accuracy                           0.75      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state50,the testing accuracy score is := 0.7730437665782494
# at random_state50,the training accuracy is: =      0.8655132101940612
# at random_state50,the confusion_matrix is:=        [[3599 1070]
#  [ 299 1064]]
# at random_state50,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4669
#          1.0       0.50      0.78      0.61      1363
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.78      0.72      6032
# weighted avg       0.83      0.77      0.79      6032
#
#
#
# at random_state51,the testing accuracy score is := 0.7541445623342176
# at random_state51,the training accuracy is: =      0.8678045358896422
# at random_state51,the confusion_matrix is:=        [[3485 1205]
#  [ 278 1064]]
# at random_state51,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.74      0.82      4690
#          1.0       0.47      0.79      0.59      1342
#
#     accuracy                           0.75      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state52,the testing accuracy score is := 0.7791777188328912
# at random_state52,the training accuracy is: =      0.8652794014496142
# at random_state52,the confusion_matrix is:=        [[3669 1034]
#  [ 298 1031]]
# at random_state52,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.78      0.85      4703
#          1.0       0.50      0.78      0.61      1329
#
#     accuracy                           0.78      6032
#    macro avg       0.71      0.78      0.73      6032
# weighted avg       0.83      0.78      0.79      6032
#
#
#
# at random_state53,the testing accuracy score is := 0.7667440318302388
# at random_state53,the training accuracy is: =      0.8640168342296002
# at random_state53,the confusion_matrix is:=        [[3552 1145]
#  [ 262 1073]]
# at random_state53,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.76      0.83      4697
#          1.0       0.48      0.80      0.60      1335
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.78      0.72      6032
# weighted avg       0.83      0.77      0.78      6032
#
#
#
# at random_state54,the testing accuracy score is := 0.7675729442970822
# at random_state54,the training accuracy is: =      0.8672433949029694
# at random_state54,the confusion_matrix is:=        [[3575 1099]
#  [ 303 1055]]
# at random_state54,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.84      4674
#          1.0       0.49      0.78      0.60      1358
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state55,the testing accuracy score is := 0.7672413793103449
# at random_state55,the training accuracy is: =      0.8663081599251812
# at random_state55,the confusion_matrix is:=        [[3584 1088]
#  [ 316 1044]]
# at random_state55,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4672
#          1.0       0.49      0.77      0.60      1360
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state56,the testing accuracy score is := 0.7607758620689655
# at random_state56,the training accuracy is: =      0.8656534954407294
# at random_state56,the confusion_matrix is:=        [[3592 1132]
#  [ 311  997]]
# at random_state56,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4724
#          1.0       0.47      0.76      0.58      1308
#
#     accuracy                           0.76      6032
#    macro avg       0.69      0.76      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state57,the testing accuracy score is := 0.7644230769230769
# at random_state57,the training accuracy is: =      0.8657937806873978
# at random_state57,the confusion_matrix is:=        [[3559 1094]
#  [ 327 1052]]
# at random_state57,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4653
#          1.0       0.49      0.76      0.60      1379
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.76      0.72      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state58,the testing accuracy score is := 0.7607758620689655
# at random_state58,the training accuracy is: =      0.8685059621229834
# at random_state58,the confusion_matrix is:=        [[3544 1116]
#  [ 327 1045]]
# at random_state58,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4660
#          1.0       0.48      0.76      0.59      1372
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state59,the testing accuracy score is := 0.753315649867374
# at random_state59,the training accuracy is: =      0.8666354921674071
# at random_state59,the confusion_matrix is:=        [[3462 1154]
#  [ 334 1082]]
# at random_state59,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.91      0.75      0.82      4616
#          1.0       0.48      0.76      0.59      1416
#
#     accuracy                           0.75      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.81      0.75      0.77      6032
#
#
#
# at random_state60,the testing accuracy score is := 0.7592838196286472
# at random_state60,the training accuracy is: =      0.8669628244096329
# at random_state60,the confusion_matrix is:=        [[3525 1162]
#  [ 290 1055]]
# at random_state60,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4687
#          1.0       0.48      0.78      0.59      1345
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state61,the testing accuracy score is := 0.7599469496021221
# at random_state61,the training accuracy is: =      0.8649053074584989
# at random_state61,the confusion_matrix is:=        [[3545 1149]
#  [ 299 1039]]
# at random_state61,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4694
#          1.0       0.47      0.78      0.59      1338
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state62,the testing accuracy score is := 0.7624336870026526
# at random_state62,the training accuracy is: =      0.8655599719429506
# at random_state62,the confusion_matrix is:=        [[3584 1127]
#  [ 306 1015]]
# at random_state62,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4711
#          1.0       0.47      0.77      0.59      1321
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state63,the testing accuracy score is := 0.7574602122015915
# at random_state63,the training accuracy is: =      0.8646247369651625
# at random_state63,the confusion_matrix is:=        [[3577 1182]
#  [ 281  992]]
# at random_state63,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4759
#          1.0       0.46      0.78      0.58      1273
#
#     accuracy                           0.76      6032
#    macro avg       0.69      0.77      0.70      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state64,the testing accuracy score is := 0.7659151193633952
# at random_state64,the training accuracy is: =      0.8681786298807576
# at random_state64,the confusion_matrix is:=        [[3552 1086]
#  [ 326 1068]]
# at random_state64,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.83      4638
#          1.0       0.50      0.77      0.60      1394
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state65,the testing accuracy score is := 0.7795092838196287
# at random_state65,the training accuracy is: =      0.865934065934066
# at random_state65,the confusion_matrix is:=        [[3648 1035]
#  [ 295 1054]]
# at random_state65,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.78      0.85      4683
#          1.0       0.50      0.78      0.61      1349
#
#     accuracy                           0.78      6032
#    macro avg       0.71      0.78      0.73      6032
# weighted avg       0.83      0.78      0.79      6032
#
#
#
# at random_state66,the testing accuracy score is := 0.7536472148541115
# at random_state66,the training accuracy is: =      0.8650455927051671
# at random_state66,the confusion_matrix is:=        [[3486 1199]
#  [ 287 1060]]
# at random_state66,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.74      0.82      4685
#          1.0       0.47      0.79      0.59      1347
#
#     accuracy                           0.75      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state67,the testing accuracy score is := 0.7650862068965517
# at random_state67,the training accuracy is: =      0.8656534954407294
# at random_state67,the confusion_matrix is:=        [[3538 1114]
#  [ 303 1077]]
# at random_state67,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4652
#          1.0       0.49      0.78      0.60      1380
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state68,the testing accuracy score is := 0.7682360742705571
# at random_state68,the training accuracy is: =      0.8661211129296236
# at random_state68,the confusion_matrix is:=        [[3608 1095]
#  [ 303 1026]]
# at random_state68,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4703
#          1.0       0.48      0.77      0.59      1329
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.72      6032
# weighted avg       0.83      0.77      0.78      6032
#
#
#
# at random_state69,the testing accuracy score is := 0.7511604774535809
# at random_state69,the training accuracy is: =      0.8675239653963058
# at random_state69,the confusion_matrix is:=        [[3451 1222]
#  [ 279 1080]]
# at random_state69,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.74      0.82      4673
#          1.0       0.47      0.79      0.59      1359
#
#     accuracy                           0.75      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state70,the testing accuracy score is := 0.7662466843501327
# at random_state70,the training accuracy is: =      0.8653261631985036
# at random_state70,the confusion_matrix is:=        [[3584 1091]
#  [ 319 1038]]
# at random_state70,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4675
#          1.0       0.49      0.76      0.60      1357
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state71,the testing accuracy score is := 0.7427055702917772
# at random_state71,the training accuracy is: =      0.8676174888940846
# at random_state71,the confusion_matrix is:=        [[3507 1249]
#  [ 303  973]]
# at random_state71,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.74      0.82      4756
#          1.0       0.44      0.76      0.56      1276
#
#     accuracy                           0.74      6032
#    macro avg       0.68      0.75      0.69      6032
# weighted avg       0.82      0.74      0.76      6032
#
#
#
# at random_state72,the testing accuracy score is := 0.7680702917771883
# at random_state72,the training accuracy is: =      0.8671966331540799
# at random_state72,the confusion_matrix is:=        [[3610 1087]
#  [ 312 1023]]
# at random_state72,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4697
#          1.0       0.48      0.77      0.59      1335
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state73,the testing accuracy score is := 0.7674071618037135
# at random_state73,the training accuracy is: =      0.8658873041851766
# at random_state73,the confusion_matrix is:=        [[3582 1103]
#  [ 300 1047]]
# at random_state73,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.84      4685
#          1.0       0.49      0.78      0.60      1347
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.72      6032
# weighted avg       0.83      0.77      0.78      6032
#
#
#
# at random_state74,the testing accuracy score is := 0.7589522546419099
# at random_state74,the training accuracy is: =      0.8652794014496142
# at random_state74,the confusion_matrix is:=        [[3553 1180]
#  [ 274 1025]]
# at random_state74,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4733
#          1.0       0.46      0.79      0.59      1299
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state75,the testing accuracy score is := 0.7692307692307693
# at random_state75,the training accuracy is: =      0.8649988309562777
# at random_state75,the confusion_matrix is:=        [[3590 1094]
#  [ 298 1050]]
# at random_state75,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4684
#          1.0       0.49      0.78      0.60      1348
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.83      0.77      0.78      6032
#
#
#
# at random_state76,the testing accuracy score is := 0.7622679045092838
# at random_state76,the training accuracy is: =      0.8655599719429506
# at random_state76,the confusion_matrix is:=        [[3479 1154]
#  [ 280 1119]]
# at random_state76,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4633
#          1.0       0.49      0.80      0.61      1399
#
#     accuracy                           0.76      6032
#    macro avg       0.71      0.78      0.72      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state77,the testing accuracy score is := 0.7574602122015915
# at random_state77,the training accuracy is: =      0.8646714987140519
# at random_state77,the confusion_matrix is:=        [[3522 1207]
#  [ 256 1047]]
# at random_state77,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.74      0.83      4729
#          1.0       0.46      0.80      0.59      1303
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state78,the testing accuracy score is := 0.7637599469496021
# at random_state78,the training accuracy is: =      0.8651858779518354
# at random_state78,the confusion_matrix is:=        [[3571 1143]
#  [ 282 1036]]
# at random_state78,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.76      0.83      4714
#          1.0       0.48      0.79      0.59      1318
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state79,the testing accuracy score is := 0.774867374005305
# at random_state79,the training accuracy is: =      0.8650455927051671
# at random_state79,the confusion_matrix is:=        [[3621 1055]
#  [ 303 1053]]
# at random_state79,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4676
#          1.0       0.50      0.78      0.61      1356
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.78      0.73      6032
# weighted avg       0.83      0.77      0.79      6032
#
#
#
# at random_state80,the testing accuracy score is := 0.7554708222811671
# at random_state80,the training accuracy is: =      0.8656534954407294
# at random_state80,the confusion_matrix is:=        [[3527 1184]
#  [ 291 1030]]
# at random_state80,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4711
#          1.0       0.47      0.78      0.58      1321
#
#     accuracy                           0.76      6032
#    macro avg       0.69      0.76      0.70      6032
# weighted avg       0.82      0.76      0.77      6032
#
#
#
# at random_state81,the testing accuracy score is := 0.7629310344827587
# at random_state81,the training accuracy is: =      0.8639233107318214
# at random_state81,the confusion_matrix is:=        [[3579 1127]
#  [ 303 1023]]
# at random_state81,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4706
#          1.0       0.48      0.77      0.59      1326
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state82,the testing accuracy score is := 0.756631299734748
# at random_state82,the training accuracy is: =      0.8660275894318448
# at random_state82,the confusion_matrix is:=        [[3481 1183]
#  [ 285 1083]]
# at random_state82,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4664
#          1.0       0.48      0.79      0.60      1368
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.82      0.76      0.77      6032
#
#
#
# at random_state83,the testing accuracy score is := 0.7747015915119363
# at random_state83,the training accuracy is: =      0.8654196866962824
# at random_state83,the confusion_matrix is:=        [[3582 1056]
#  [ 303 1091]]
# at random_state83,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4638
#          1.0       0.51      0.78      0.62      1394
#
#     accuracy                           0.77      6032
#    macro avg       0.72      0.78      0.73      6032
# weighted avg       0.83      0.77      0.79      6032
#
#
#
# at random_state84,the testing accuracy score is := 0.7697281167108754
# at random_state84,the training accuracy is: =      0.8667290156651859
# at random_state84,the confusion_matrix is:=        [[3578 1068]
#  [ 321 1065]]
# at random_state84,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4646
#          1.0       0.50      0.77      0.61      1386
#
#     accuracy                           0.77      6032
#    macro avg       0.71      0.77      0.72      6032
# weighted avg       0.82      0.77      0.78      6032
#
#
#
# at random_state85,the testing accuracy score is := 0.7601127320954907
# at random_state85,the training accuracy is: =      0.8655132101940612
# at random_state85,the confusion_matrix is:=        [[3526 1188]
#  [ 259 1059]]
# at random_state85,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4714
#          1.0       0.47      0.80      0.59      1318
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.78      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state86,the testing accuracy score is := 0.7647546419098143
# at random_state86,the training accuracy is: =      0.8645312134673837
# at random_state86,the confusion_matrix is:=        [[3594 1094]
#  [ 325 1019]]
# at random_state86,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4688
#          1.0       0.48      0.76      0.59      1344
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state87,the testing accuracy score is := 0.7621021220159151
# at random_state87,the training accuracy is: =      0.8665887304185177
# at random_state87,the confusion_matrix is:=        [[3536 1102]
#  [ 333 1061]]
# at random_state87,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.91      0.76      0.83      4638
#          1.0       0.49      0.76      0.60      1394
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state88,the testing accuracy score is := 0.7490053050397878
# at random_state88,the training accuracy is: =      0.8668225391629647
# at random_state88,the confusion_matrix is:=        [[3460 1214]
#  [ 300 1058]]
# at random_state88,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.74      0.82      4674
#          1.0       0.47      0.78      0.58      1358
#
#     accuracy                           0.75      6032
#    macro avg       0.69      0.76      0.70      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state89,the testing accuracy score is := 0.7601127320954907
# at random_state89,the training accuracy is: =      0.8644376899696049
# at random_state89,the confusion_matrix is:=        [[3518 1182]
#  [ 265 1067]]
# at random_state89,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4700
#          1.0       0.47      0.80      0.60      1332
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state90,the testing accuracy score is := 0.7654177718832891
# at random_state90,the training accuracy is: =      0.8663081599251812
# at random_state90,the confusion_matrix is:=        [[3597 1114]
#  [ 301 1020]]
# at random_state90,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.84      4711
#          1.0       0.48      0.77      0.59      1321
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.77      0.78      6032
#
#
#
# at random_state91,the testing accuracy score is := 0.7529840848806366
# at random_state91,the training accuracy is: =      0.8659808276829554
# at random_state91,the confusion_matrix is:=        [[3495 1163]
#  [ 327 1047]]
# at random_state91,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.91      0.75      0.82      4658
#          1.0       0.47      0.76      0.58      1374
#
#     accuracy                           0.75      6032
#    macro avg       0.69      0.76      0.70      6032
# weighted avg       0.81      0.75      0.77      6032
#
#
#
# at random_state92,the testing accuracy score is := 0.7753647214854111
# at random_state92,the training accuracy is: =      0.8679915828852
# at random_state92,the confusion_matrix is:=        [[3577 1045]
#  [ 310 1100]]
# at random_state92,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4622
#          1.0       0.51      0.78      0.62      1410
#
#     accuracy                           0.78      6032
#    macro avg       0.72      0.78      0.73      6032
# weighted avg       0.83      0.78      0.79      6032
#
#
#
# at random_state93,the testing accuracy score is := 0.7531498673740054
# at random_state93,the training accuracy is: =      0.8652326397007248
# at random_state93,the confusion_matrix is:=        [[3467 1171]
#  [ 318 1076]]
# at random_state93,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.82      4638
#          1.0       0.48      0.77      0.59      1394
#
#     accuracy                           0.75      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.81      0.75      0.77      6032
#
#
#
# at random_state94,the testing accuracy score is := 0.7596153846153846
# at random_state94,the training accuracy is: =      0.8672901566518588
# at random_state94,the confusion_matrix is:=        [[3536 1167]
#  [ 283 1046]]
# at random_state94,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.93      0.75      0.83      4703
#          1.0       0.47      0.79      0.59      1329
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.77      0.71      6032
# weighted avg       0.83      0.76      0.78      6032
#
#
#
# at random_state95,the testing accuracy score is := 0.7541445623342176
# at random_state95,the training accuracy is: =      0.8657002571896188
# at random_state95,the confusion_matrix is:=        [[3487 1168]
#  [ 315 1062]]
# at random_state95,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.82      4655
#          1.0       0.48      0.77      0.59      1377
#
#     accuracy                           0.75      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state96,the testing accuracy score is := 0.7538129973474801
# at random_state96,the training accuracy is: =      0.8657002571896188
# at random_state96,the confusion_matrix is:=        [[3511 1178]
#  [ 307 1036]]
# at random_state96,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4689
#          1.0       0.47      0.77      0.58      1343
#
#     accuracy                           0.75      6032
#    macro avg       0.69      0.76      0.70      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state97,the testing accuracy score is := 0.7529840848806366
# at random_state97,the training accuracy is: =      0.8657470189385083
# at random_state97,the confusion_matrix is:=        [[3519 1191]
#  [ 299 1023]]
# at random_state97,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83      4710
#          1.0       0.46      0.77      0.58      1322
#
#     accuracy                           0.75      6032
#    macro avg       0.69      0.76      0.70      6032
# weighted avg       0.82      0.75      0.77      6032
#
#
#
# at random_state98,the testing accuracy score is := 0.7619363395225465
# at random_state98,the training accuracy is: =      0.8658873041851766
# at random_state98,the confusion_matrix is:=        [[3528 1118]
#  [ 318 1068]]
# at random_state98,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.76      0.83      4646
#          1.0       0.49      0.77      0.60      1386
#
#     accuracy                           0.76      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.76      0.78      6032
#
#
#
# at random_state99,the testing accuracy score is := 0.76657824933687
# at random_state99,the training accuracy is: =      0.87509936871639
# at random_state99,the confusion_matrix is:=        [[3606 1090]
#  [ 318 1018]]
# at random_state99,the classification_report is:=                 precision    recall  f1-score   support
#
#          0.0       0.92      0.77      0.84      4696
#          1.0       0.48      0.76      0.59      1336
#
#     accuracy                           0.77      6032
#    macro avg       0.70      0.76      0.71      6032
# weighted avg       0.82      0.77      0.78      6032

# %% [markdown]
# here this is the testing & training score for  GausianNB classifier model which is not gd as KNN model.

# %% [markdown]
# # Use GridSearchCV method

# %% [markdown]
# DecisionTreeClassifier

# %%
from sklearn.model_selection import GridSearchCV
dtc=DecisionTreeClassifier()

# %%
grid_param={'criterion':['ginni','entropy']}
grid=GridSearchCV(dtc,grid_param)
grid.fit(train_x,train_y)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['ginni', 'entropy']})

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'entropy'}

# %%
dtc=DecisionTreeClassifier(criterion='entropy')
dtc.fit(train_x,train_y)
dtcpred=dtc.predict(test_x)
print(f"dtc training score is:= {dtc.score(train_x,train_y)}")
print(f"dtc testing score is:= {accuracy_score(test_y,dtcpred)}")
print(f"confusion matrix is:={confusion_matrix(test_y,dtcpred)}")
print(f"classification report is:={classification_report(test_y,dtcpred)}")
# Out:
# dtc training score is:= 0.9999532382511106
# dtc testing score is:= 0.8154840848806366
# confusion matrix is:=[[4147  549]
#  [ 564  772]]
# classification report is:=              precision    recall  f1-score   support
#
#          0.0       0.88      0.88      0.88      4696
#          1.0       0.58      0.58      0.58      1336
#
#     accuracy                           0.82      6032
#    macro avg       0.73      0.73      0.73      6032
# weighted avg       0.81      0.82      0.82      6032

# %% [markdown]
# # SVC classifier

# %%
svc=SVC()

# %%
grid_param={'kernel':['rbf','poly','linear']}
grid=GridSearchCV(svc,grid_param)
grid.fit(train_x,train_y)
# Out:
# GridSearchCV(estimator=SVC(), param_grid={'kernel': ['rbf', 'poly', 'linear']})

# %%
print(grid.best_params_)
# Out:
# {'kernel': 'rbf'}

# %%
svc=SVC()
svc.fit(train_x,train_y)
svcpred=svc.predict(test_x)
print(f"svc training score is:= {svc.score(train_x,train_y)}")
print(f"svc testing score is:= {accuracy_score(test_y,svcpred)}")
print(f"confusion matrix is:={confusion_matrix(test_y,svcpred)}")
print(f"classification report is:={classification_report(test_y,svcpred)}")
# Out:
# svc training score is:= 0.8425064297404723
# svc testing score is:= 0.843998673740053
# confusion matrix is:=[[4452  244]
#  [ 697  639]]
# classification report is:=              precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90      4696
#          1.0       0.72      0.48      0.58      1336
#
#     accuracy                           0.84      6032
#    macro avg       0.79      0.71      0.74      6032
# weighted avg       0.83      0.84      0.83      6032

# %% [markdown]
# # Hence the SVC model has the Better model perfomance in all models
# Training score=84.2%
# testing score =84.39%.

# %% [markdown]
# # Save the model for production purpose

# %%
import joblib
Income_file=joblib.dump(svc,"Incomefile.obj")
Income_file
# Out:
# ['Incomefile.obj']
